# %% [markdown]
# # IMPORT DES DONNÉES

# %%
import pandas as pd

d1dispo_alimentaire_csv = pd.read_csv ('dispo_alimentaire.csv')
d2aide_alimentaire_csv = pd.read_csv ('aide_alimentaire.csv')
d3population_csv= pd.read_csv ('population.csv')
d4sous_nutrition_csv= pd.read_csv ('sous_nutrition.csv')

import matplotlib.pyplot as gr

import seaborn as sb
# Out:
# /Users/juanlu/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # DISPLAY DES DONNÉES

# %%
display (d1dispo_alimentaire_csv)
display(d2aide_alimentaire_csv)
display(d3population_csv)
display(d4sous_nutrition_csv)
# Out:
#                Zone                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15600  Îles Salomon       Viande de Suides   animale                    NaN
# 15601  Îles Salomon    Viande de Volailles   animale                    NaN
# 15602  Îles Salomon          Viande, Autre   animale                    NaN
# 15603  Îles Salomon                    Vin  vegetale                    NaN
# 15604  Îles Salomon         Épices, Autres  vegetale                    NaN
#
# ...

# %% [markdown]
# # DISPO ALIMENTAIRE

# %% [markdown]
# ## D1 dispoalimentaire_csv DESCRIBE ET INFO

# %%
d1dispo_alimentaire_csv.describe(include='all')
# Out:
#          Zone           Produit   Origine  Aliments pour animaux  \
# count   15605             15605     15605            2720.000000
# unique    174                98         2                    NaN
# top      Inde  Abats Comestible  vegetale                    NaN
# freq       97               174     11896                    NaN
# mean      NaN               NaN       NaN             479.501838
# std       NaN               NaN       NaN            4240.119637
# min       NaN               NaN       NaN               0.000000
# 25%       NaN               NaN       NaN               0.000000
# 50%       NaN               NaN       NaN               4.000000
# 75%       NaN               NaN       NaN              74.000000
# max       NaN               NaN       NaN          150000.000000
#
#         Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# count           5496.000000                                    14241.000000
# ...

# %%
d1dispo_alimentaire_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15605 entries, 0 to 15604
# Data columns (total 18 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Zone                                                           15605 non-null  object
#  1   Produit                                                        15605 non-null  object
#  2   Origine                                                        15605 non-null  object
#  3   Aliments pour animaux                                          2720 non-null   float64
#  4   Autres Utilisations                                            5496 non-null   float64
#  5   Disponibilité alimentaire (Kcal/personne/jour)                 14241 non-null  float64
#  6   Disponibilité alimentaire en quantité (kg/personne/an)         14015 non-null  float64
# ...

# %%
# D1 On va chercher des valeurs qui sont en bas de 0 pour néttoyer des données:
d1dispo_alimentaire_csv=d1dispo_alimentaire_csv[d1dispo_alimentaire_csv['Disponibilité alimentaire (Kcal/personne/jour)']>=0]

# %%
# D1_dispoalimentaire_csv DESCRIBE ET INFO APRÈS AVOIR ELIMINEE LA LIGNE
d1dispo_alimentaire_csv.describe(include='all')
# Out:
#             Zone           Produit   Origine  Aliments pour animaux  \
# count      14240             14240     14240            2261.000000
# unique       174                97         2                    NaN
# top     Cameroun  Abats Comestible  vegetale                    NaN
# freq          91               174     10536                    NaN
# mean         NaN               NaN       NaN             549.867758
# std          NaN               NaN       NaN            4637.452469
# min          NaN               NaN       NaN               0.000000
# 25%          NaN               NaN       NaN               0.000000
# 50%          NaN               NaN       NaN               6.000000
# 75%          NaN               NaN       NaN              95.000000
# max          NaN               NaN       NaN          150000.000000
#
#         Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# ...

# %% [markdown]
# ## D1 HOMOGENEISER LES NOMS DES ZONES DES TABLES

# %%
d1dispo_alimentaire_csv.loc[d1dispo_alimentaire_csv['Zone']=='Tchéquie (la)', 'Zone']='Tchéquie'
d1dispo_alimentaire_csv.loc[d1dispo_alimentaire_csv['Zone']=='Royaume-Uni', 'Zone']=(
    'Royaume-Uni de Grande-Bretagne et d\'Irlande du Nord')

# %%
d1dispo_alimentaire_csv.isnull().sum()
# Out:
# Zone                                                                 0
# Produit                                                              0
# Origine                                                              0
# Aliments pour animaux                                            11979
# Autres Utilisations                                               9390
# Disponibilité alimentaire (Kcal/personne/jour)                       0
# Disponibilité alimentaire en quantité (kg/personne/an)             245
# Disponibilité de matière grasse en quantité (g/personne/jour)     2447
# Disponibilité de protéines en quantité (g/personne/jour)          2680
# Disponibilité intérieure                                           223
# Exportations - Quantité                                           2974
# Importations - Quantité                                            602
# Nourriture                                                         245
# ...

# %%
d1dispo_alimentaire_csv=d1dispo_alimentaire_csv.fillna(0)

# %% [markdown]
# ## CHANGER G/PERSONNE/JOUR POUR KG/PERSONNE/AN

# %%
d1dispo_alimentaire_csv['Disponibilité de matière grasse en quantité (kg/personne/an)']=( 
    d1dispo_alimentaire_csv['Disponibilité de matière grasse en quantité (g/personne/jour)']*365/1000)
d1dispo_alimentaire_csv['Disponibilité de protéines en quantité (kg/personne/an)']=(
    d1dispo_alimentaire_csv['Disponibilité de protéines en quantité (g/personne/jour)']*365/1000)
del d1dispo_alimentaire_csv['Disponibilité de matière grasse en quantité (g/personne/jour)']
del d1dispo_alimentaire_csv['Disponibilité de protéines en quantité (g/personne/jour)']

# %% [markdown]
# # AIDE ALIMENTAIRE

# %% [markdown]
# ## D2 aide_alimentaire_csv DESCRIBE ET INFO

# %%
d2aide_alimentaire_csv.describe(include='all')
# Out:
#        Pays bénéficiaire        Année       Produit         Valeur
# count               1475  1475.000000          1475    1475.000000
# unique                76          NaN            16            NaN
# top              Algérie          NaN  Non-céréales            NaN
# freq                  39          NaN           220            NaN
# mean                 NaN  2014.054237           NaN    7481.966780
# std                  NaN     0.946916           NaN   23339.531424
# min                  NaN  2013.000000           NaN       0.000000
# 25%                  NaN  2013.000000           NaN     287.500000
# 50%                  NaN  2014.000000           NaN    1178.000000
# 75%                  NaN  2015.000000           NaN    4334.500000
# max                  NaN  2016.000000           NaN  265013.000000

# %%
d2aide_alimentaire_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pays bénéficiaire  1475 non-null   object
#  1   Année              1475 non-null   int64
#  2   Produit            1475 non-null   object
#  3   Valeur             1475 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 46.2+ KB

# %% [markdown]
# # POPULATION

# %% [markdown]
# ## D3 population_csv DESCRIBE ET INFO

# %%
d3population_csv.describe(include='all')
# Out:
#                Zone        Année        Valeur
# count          1416  1416.000000  1.416000e+03
# unique          236          NaN           NaN
# top     Afghanistan          NaN           NaN
# freq              6          NaN           NaN
# mean            NaN  2015.500000  3.144793e+04
# std             NaN     1.708428  1.300812e+05
# min             NaN  2013.000000  7.930000e-01
# 25%             NaN  2014.000000  3.783410e+02
# 50%             NaN  2015.500000  5.126480e+03
# 75%             NaN  2017.000000  1.930666e+04
# max             NaN  2018.000000  1.427648e+06

# %%
d3population_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1416 entries, 0 to 1415
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1416 non-null   object
#  1   Année   1416 non-null   int64
#  2   Valeur  1416 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.3+ KB

# %%
# D3 JE FAIS LA SOMME DES LIGNES QUI SONT DE L'ANNÉE 2017 (RESULTAT: 236)
d3population_csv[d3population_csv['Année']== 2017 ].count()
# Out:
# Zone      236
# Année     236
# Valeur    236
# dtype: int64

# %%
# D3 JE LAISSE JUSTE LES DONNÉES DE L'ANNÉE 2017
d3population_csv=d3population_csv[d3population_csv['Année']==2017]

# %% [markdown]
# ## D3 JE CONVERTIS LA POPULATION AU NOMBRE REELLE (MULTIPLIER PAR 1000)

# %%
d3population_csv['Valeur']= d3population_csv['Valeur'] *1000

# %% [markdown]
# ##### D3 JE MODIFIE LE NOM DE LA COLONNE : VALEUR PAR POPULATION

# %%
d3population_csv.rename(columns={'Valeur': 'Population'}, inplace=True)
d3population_csv['Population']=d3population_csv['Population'].astype(int)

# %%
d3population_csv
# Out:
#                                         Zone  Année  Population
# 4                                Afghanistan   2017    36296113
# 10                            Afrique du Sud   2017    57009756
# 16                                   Albanie   2017     2884169
# 22                                   Algérie   2017    41389189
# 28                                 Allemagne   2017    82658409
# ...                                      ...    ...         ...
# 1390  Venezuela (République bolivarienne du)   2017    29402484
# 1396                                Viet Nam   2017    94600648
# 1402                                   Yémen   2017    27834819
# 1408                                  Zambie   2017    16853599
# 1414                                Zimbabwe   2017    14236595
#
# [236 rows x 3 columns]

# %%
pop=d3population_csv['Population'].sum()
d3population_csv['Population'].sum()
#D3 JE FAIS LA SOMME DE LA POPULATION MONDIALE POUR VOIR SI C'EST UN VALEUR COHERENTE
# Out:
# 7548134097

# %% [markdown]
# # SOUS NUTRITION

# %% [markdown]
# ## D4 sous_nutrition_csv DESCRIBE ET INFO

# %%
d4sous_nutrition_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1218 non-null   object
#  1   Année   1218 non-null   object
#  2   Valeur  624 non-null    object
# dtypes: object(3)
# memory usage: 28.7+ KB

# %%
d4sous_nutrition_csv.describe(include='all')
# Out:
#                Zone      Année Valeur
# count          1218       1218    624
# unique          203          6    139
# top     Afghanistan  2012-2014   <0.1
# freq              6        203    120

# %%
# On a valeurs float64 qui ne sont pas une variable float en "Afganistan, par example" avec valeur <0.1
d4sous_nutrition_csv[d4sous_nutrition_csv['Valeur']== '<0.1' ].count()
# Out:
# Zone      120
# Année     120
# Valeur    120
# dtype: int64

# %%
#Il y a 20 zones en 2017 qui ont comment valeur de sous nutrition '<0.1'
d4sous_nutrition_csv[ (d4sous_nutrition_csv['Valeur']== '<0.1') & (
    d4sous_nutrition_csv['Année']== '2016-2018') ].count()
# Out:
# Zone      20
# Année     20
# Valeur    20
# dtype: int64

# %%
# Ici, j'ai changé  toutes les valeurs <0.1 pour 0, parce que <0.1 n'est pas une variable ni int ni float
d4sous_nutrition_csv.loc[d4sous_nutrition_csv['Valeur']== '<0.1' , 'Valeur'] =0

# %%
d4sous_nutrition_csv.isnull().sum()
# Out:
# Zone        0
# Année       0
# Valeur    594
# dtype: int64

# %%
# MAINTENANT JE VAIS NETOYER DES DONNÉES NULS
d4sous_nutrition_csv=d4sous_nutrition_csv.fillna(0)

# %%
d4sous_nutrition_csv=d4sous_nutrition_csv[d4sous_nutrition_csv['Année']=='2016-2018']

# %%
d4sous_nutrition_csv['Valeur']=d4sous_nutrition_csv['Valeur'].astype(float)

# %%
## JE CHANGE NOM COLOMNE VALEUR PAR SOUS NUTRITION ET
## JE CHANGE NOMBRE DE MILLONS À MILLONS DE PERSONNES EN SOUR NUTRITION
d4sous_nutrition_csv['Sous nutrition']=d4sous_nutrition_csv['Valeur']*1000000
del d4sous_nutrition_csv['Valeur']
del d4sous_nutrition_csv['Année']

# %%
d4sous_nutrition_csv['Sous nutrition']=d4sous_nutrition_csv['Sous nutrition'].astype(int)

# %%
display(d4sous_nutrition_csv)
# Out:
#                                         Zone  Sous nutrition
# 4                                Afghanistan        10500000
# 10                            Afrique du Sud         3100000
# 16                                   Albanie          100000
# 22                                   Algérie         1300000
# 28                                 Allemagne               0
# ...                                      ...             ...
# 1192  Venezuela (République bolivarienne du)         8000000
# 1198                                Viet Nam         6500000
# 1204                                   Yémen               0
# 1210                                  Zambie               0
# 1216                                Zimbabwe               0
#
# [203 rows x 2 columns]

# %% [markdown]
# # MERGE

# %% [markdown]
# ## JE FAIS MERGE DE DISPO ALIMENTAIRE (D1) ET POPULATION (D3)

# %%
d34= pd.merge(d3population_csv, d4sous_nutrition_csv , on='Zone', how='left')

# %%
d34.shape
# Out:
# (236, 4)

# %%
# j'ai besoin merge pop et sous nutrition et apres avec dispo alimentaire

# %%
# MAINTENANT JE VAIS NETOYER DES DONNÉES NULS
d34=d34.fillna(0)

# %%
#Je fais la proportion de personnes en sous nutrition
d34['% Sous Nutrition']=d34['Sous nutrition']/d34['Population']

# %%
d34['% Sous Nutrition']=d34['% Sous Nutrition'].round(4)*100

# %% [markdown]
# ## MERGE DISPO ALIMENTAIRE, POPULATION ET SOUS NUTRITION

# %%
d134= pd.merge(d34, d1dispo_alimentaire_csv , on='Zone')#, how='left') #left join population avec des autres

# %%
d134.shape
# Out:
# (14240, 22)

# %%
d134.Zone.nunique()
# Out:
# 174

# %%
d134['Sous nutrition']=d134['Sous nutrition'].astype('float')

# %% [markdown]
# # Analyses Marc

# %% [markdown]
# ## % SOUS NUTRITION DANS LE MONDE

# %%
print ("\n\n\nLa proportion de personnes en état de sous-nutrition:\n\n",(d134['Sous nutrition'] .sum()/ d134['Population'].sum()*100).round(2) )
# Out:
# La proportion de personnes en état de sous-nutrition:
#
#  7.19

# %% [markdown]
# ## % MOYENNE SOUS NUTRITION DANS SEULEMENT DES ZONES EN SOUS NUTRITION

# %%
(d134['Sous nutrition'][d134['% Sous Nutrition']>0].sum()/ d134['Population'][d134['% Sous Nutrition']>0].sum()*100).round(4)
# Out:
# 12.767

# %%
d134=d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition', 'Origine']).sum()
d134=d134.reset_index()

# %%
d134.shape
# Out:
# (348, 21)

# %%
d134.Origine.nunique()
# Out:
# 2

# %%
# DISPO ALIMENTAIRE EN CALORIE PAR POPULATION DANS CHAQUE PAYS
d134['Dispo alimentaire kcal/personne/jour * Population']=(
    d134['Disponibilité alimentaire (Kcal/personne/jour)']*d134['Population'])

# %%
kcal_monde_animale=d134['Dispo alimentaire kcal/personne/jour * Population'][d134['Origine']=='animale'].sum()

# %%
kcal_monde_vegetale=d134['Dispo alimentaire kcal/personne/jour * Population'][d134['Origine']=='vegetale'].sum()

# %%
d134=d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition']).sum()
d134=d134.reset_index()

# %%
d134.shape
# Out:
# (174, 21)

# %%
kcal_monde=d134['Dispo alimentaire kcal/personne/jour * Population'].sum()

# %% [markdown]
# ## NOMBRE TEORIQUE DES PERSONNES QUI PEUT ETRE NOURRIES ET PROPORTION

# %%
print(
        "\n\nPersonnes dans le monde:\n", pop,
         "\n\nPersonnes qui peuvent etre nourries:\n", 
      (kcal_monde/2500).round(0),
      "\n\nProportion de personnes qui peuvent etre nourries:\n" , 
      ((kcal_monde/2500)*100/pop).round(2),


     )
# Out:
# Personnes dans le monde:
#  7548134097
#
# Personnes qui peuvent etre nourries:
#  8473936113.0
#
# Proportion de personnes qui peuvent etre nourries:
#  112.27

# %% [markdown]
# ## NOMBRE TEORIQUE DES PERSONNES QUI PEUT ETRE NOURRIES D'ORIGINE VEGETALE

# %%
print(
    "\nProportion de personnes qui peuvent etre nourries d'origine vegetale:\n" , 
      ((kcal_monde_vegetale/2500)*100/pop).round(2),
     "\n\nPersonnes qui peuvent etre nourries avec nourriture d'origine vegetale:\n", 
      (kcal_monde_vegetale/2500).round(0)
     )
# Out:
# Proportion de personnes qui peuvent etre nourries d'origine vegetale:
#  92.48
#
# Personnes qui peuvent etre nourries avec nourriture d'origine vegetale:
#  6980874784.0

# %% [markdown]
# ## CALORIES PAR PERSONE DANS LE MONDE, PROPORTION JUSTE ORIGINE ANIMALE, ETC

# %%
print("Personnes qui peut etre nourries avec nourriture d'origine animale:\n", 
      (kcal_monde_animale/2500).round(0),


    "\n\n\nProportion de personnes qui peut etre nourries (animale):\n" , 
      ((kcal_monde_animale/2500)*100/pop).round(2),
     "\n\n\n\nCalories par personne:\n", (kcal_monde/pop).round(2),
      "\n\nCalories par persone d'Origine animale:\n", (kcal_monde_animale/pop).round(2),
      "\n\nCalories par persone d'Origine vegetale:\n", (kcal_monde_vegetale/pop).round(2)   

     
     )
# Out:
# Personnes qui peut etre nourries avec nourriture d'origine animale:
#  1493061329.0
#
#
# Proportion de personnes qui peut etre nourries (animale):
#  19.78
#
#
#
# Calories par personne:
#  2806.63
#
# Calories par persone d'Origine animale:
#  494.51
#
# Calories par persone d'Origine vegetale:
#  2312.12

# %%
d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition']).sum()#, 'Origine']).sum()
# Out:
#                                                                         Aliments pour animaux  \
# Zone                  Année Population Sous nutrition % Sous Nutrition
# Afghanistan           2017  36296113   10500000.0     28.93                             687.0
# Afrique du Sud        2017  57009756   3100000.0      5.44                             5309.0
# Albanie               2017  2884169    100000.0       3.47                              659.0
# Algérie               2017  41389189   1300000.0      3.14                             4351.0
# Allemagne             2017  82658409   0.0            0.00                            30082.0
# ...                                                                                       ...
# Émirats arabes unis   2017  9487203    300000.0       3.16                              627.0
# Équateur              2017  16785361   1500000.0      8.94                             1062.0
# ...

# %%
d134['Population'].sum(),  d134['Sous nutrition'].sum(), d134['Sous nutrition'].sum()/d134['Population'].sum()
# Out:
# (7369269318, 535700000.0, 0.07269377422419779)

# %%
dg=d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition']).sum()
#dg['% Pertes']=dg['Pertes']/dg['Disponibilité intérieure']

# %% [markdown]
# # PERTES ,NOURRITURE, ALIMENTS POUR ANIMAUX EN % en functione de disponibilité interieure

# %%
print ("\n\nPertes:\n\n", (d134['Pertes'].sum()*100/d134['Disponibilité intérieure'].sum()).round(2))
# Out:
# Pertes:
#
#  4.96

# %%
print ("\n\nNourriture:\n\n", (dg['Nourriture'].sum()*100/dg['Disponibilité intérieure'].sum()).round(2))
# Out:
# Nourriture:
#
#  54.08

# %%
print ("\n\nAliments pour animaux:\n\n", (dg['Aliments pour animaux'].sum()*100/dg['Disponibilité intérieure'].sum()).round(2))
# Out:
# Aliments pour animaux:
#
#  13.79

# %% [markdown]
# # Analyses Melanie

# %%
d34t=d34 [ (d34['% Sous Nutrition']>0) ].sort_values('% Sous Nutrition', ascending = False)#.head(10)

# %%
cols=['Zone','Population','Sous nutrition','% Sous Nutrition']

# %%
display(d34t[cols].head(10))#.sort_values('Population', ascending = False))
# Out:
#                                            Zone  Population  Sous nutrition  \
# 87                                        Haïti    10982366       5300000.0
# 181  République populaire démocratique de Corée    25429825      12000000.0
# 128                                  Madagascar    25570512      10500000.0
# 122                                     Libéria     4702226       1800000.0
# 119                                     Lesotho     2091534        800000.0
# 216                                       Tchad    15016753       5700000.0
# 186                                      Rwanda    11980961       4200000.0
# 145                                  Mozambique    28649018       9400000.0
# 219                                 Timor-Leste     1243258        400000.0
# 0                                   Afghanistan    36296113      10500000.0
#
#      % Sous Nutrition
# 87              48.26
# 181             47.19
# 128             41.06
# 122             38.28
# ...

# %%
gr.figure(figsize=(20,10))
sb.scatterplot(data=d34t, x='Population', y='% Sous Nutrition')
gr.grid()
gr.show()
#Inde, Indonésie, Pakistan et Nigéria

# %% [markdown]
# ## La proportion de personnes en état de sous-nutrition par pays

# %%
#d34[['Zone', 'Population','Sous nutrition', '% Sous Nutrition']][(d34['% Sous Nutrition']>40) ]

# %%
d2a=d2aide_alimentaire_csv.groupby(['Pays bénéficiaire']).sum()

# %%
d2a=d2a.reset_index()

# %%
#d2a['Continent']='Monde'
d2a.loc[(
        (d2a['Pays bénéficiaire']=='Libye' )|
        (d2a['Pays bénéficiaire']=='Afrique du Sud')|
        (d2a['Pays bénéficiaire']=='Angola')|
        (d2a['Pays bénéficiaire']=='Algérie')|
        (d2a['Pays bénéficiaire']=='Égypte')|
        (d2a['Pays bénéficiaire']=='Éthiopie')|
        (d2a['Pays bénéficiaire']=='Zambie')|
        (d2a['Pays bénéficiaire']=='Zimbabwe')|
        (d2a['Pays bénéficiaire']=='Tunisie')|
        (d2a['Pays bénéficiaire']=='Botswana')|
        (d2a['Pays bénéficiaire']=='Burkina Faso')|
        (d2a['Pays bénéficiaire']=='Cabo Verde')|
        (d2a['Pays bénéficiaire']=='Cameroun')|
        (d2a['Pays bénéficiaire']=='Togo')|
        (d2a['Pays bénéficiaire']=='Sénégal')|
        (d2a['Pays bénéficiaire']=='Bénin')|
        (d2a['Pays bénéficiaire']=='Congo')|
        (d2a['Pays bénéficiaire']=='Soudan')|
        (d2a['Pays bénéficiaire']=='Djibouti')|
        (d2a['Pays bénéficiaire']=='Sao Tomé-et-Principe')|
        (d2a['Pays bénéficiaire']=='Sierra Leone')|
        (d2a['Pays bénéficiaire']=='Tchad')|
        (d2a['Pays bénéficiaire']=='République-Unie de Tanzanie')|
        (d2a['Pays bénéficiaire']=='Côte d\'Ivoire')|
        (d2a['Pays bénéficiaire']=='Gabon')|
        (d2a['Pays bénéficiaire']=='Eswatini')|
        (d2a['Pays bénéficiaire']=='Gambie')|
        (d2a['Pays bénéficiaire']=='Ghana')|
        (d2a['Pays bénéficiaire']=='Rwanda')|
        (d2a['Pays bénéficiaire']=='République centrafricaine')|
        (d2a['Pays bénéficiaire']=='Guinée')|
        (d2a['Pays bénéficiaire']=='Mozambique')|
        (d2a['Pays bénéficiaire']=='Mauritanie')|
        (d2a['Pays bénéficiaire']=='Mali')|
        (d2a['Pays bénéficiaire']=='Kenya')|
        (d2a['Pays bénéficiaire']=='Nigéria')|
        (d2a['Pays bénéficiaire']=='Niger')|
        (d2a['Pays bénéficiaire']=='Maroc')|
        (d2a['Pays bénéficiaire']=='Malawi')|
        (d2a['Pays bénéficiaire']=='Maurice')|
        (d2a['Pays bénéficiaire']=='Ouganda')|
        (d2a['Pays bénéficiaire']=='Namibie')|
        (d2a['Pays bénéficiaire']=='Libéria')|
        (d2a['Pays bénéficiaire']=='Madagascar')|
        (d2a['Pays bénéficiaire']=='Guinée-Bissau')|
        (d2a['Pays bénéficiaire']=='Lesotho')|
        (d2a['Pays bénéficiaire']=='Burundi')|
        (d2a['Pays bénéficiaire']=='Comores')|
        (d2a['Pays bénéficiaire']=='Somalie')|
        (d2a['Pays bénéficiaire']=='République démocratique du Congo')|
        (d2a['Pays bénéficiaire']=='Soudan du Sud')|
        (d2a['Pays bénéficiaire']=='Swaziland')
        
        
       ), 'Continent']='Afrique'

d2a.loc[(
        (d2a['Pays bénéficiaire']=='Albanie' )|
        (d2a['Pays bénéficiaire']=='Allemagne')|
        (d2a['Pays bénéficiaire']=='Autriche')|
        (d2a['Pays bénéficiaire']=='Ukraine')|
        (d2a['Pays bénéficiaire']=='Bosnie-Herzégovine')|
        (d2a['Pays bénéficiaire']=='Belgique')|
        (d2a['Pays bénéficiaire']=='Tchéquie')|
        (d2a['Pays bénéficiaire']=='Bulgarie')|
        (d2a['Pays bénéficiaire']=='Suède')|
        (d2a['Pays bénéficiaire']=='Suisse')|
        (d2a['Pays bénéficiaire']=='Bélarus')|
        (d2a['Pays bénéficiaire']=='Slovaquie')|
        (d2a['Pays bénéficiaire']=='Slovénie')|
        (d2a['Pays bénéficiaire']=='Serbie')|
        (d2a['Pays bénéficiaire']=='Chypre')|
        (d2a['Pays bénéficiaire']=='Croatie')|
        (d2a['Pays bénéficiaire']=='Danemark')|
        (d2a['Pays bénéficiaire']=='Espagne')|
        (d2a['Pays bénéficiaire']=='Estonie')|
        (d2a['Pays bénéficiaire']=='France')|
        (d2a['Pays bénéficiaire']=='Finlande')|
        (d2a['Pays bénéficiaire']=='Fédération de Russie')|
    #Russie je vais le miser sur Europe pour des stats
        (d2a['Pays bénéficiaire']=='République de Moldova')|
        (d2a['Pays bénéficiaire']=='Grèce')|
        (d2a['Pays bénéficiaire']=='Roumanie')|
        (d2a['Pays bénéficiaire']=='Pologne')|
        (d2a['Pays bénéficiaire']=='Portugal')|
        (d2a['Pays bénéficiaire']=='Royaume-Uni de Grande-Bretagne et d\'Irlande du Nord')|
        (d2a['Pays bénéficiaire']=='Pays-Bas')|
        (d2a['Pays bénéficiaire']=='Lituanie')|
        (d2a['Pays bénéficiaire']=='Luxembourg')|
        (d2a['Pays bénéficiaire']=='Italie')|
        (d2a['Pays bénéficiaire']=='Lettonie')|
        (d2a['Pays bénéficiaire']=='Hongrie')|
        (d2a['Pays bénéficiaire']=='Monténégro')|
        (d2a['Pays bénéficiaire']=='Malte')|
        (d2a['Pays bénéficiaire']=='Norvège')|
        (d2a['Pays bénéficiaire']=='Macédoine du Nord')|
        (d2a['Pays bénéficiaire']=='Irlande')|
        (d2a['Pays bénéficiaire']=='Islande')
        
        
       ), 'Continent']='Europe'

d2a.loc[(
        (d2a['Pays bénéficiaire']=='Émirats arabes unis' )|
        (d2a['Pays bénéficiaire']=='Arabie saoudite')|
        (d2a['Pays bénéficiaire']=='Arménie')|
        (d2a['Pays bénéficiaire']=='Viet Nam')|
        (d2a['Pays bénéficiaire']=='Yémen')|
        (d2a['Pays bénéficiaire']=='Azerbaïdjan')|
        (d2a['Pays bénéficiaire']=='Bangladesh')|
        (d2a['Pays bénéficiaire']=='Turkménistan')|
        (d2a['Pays bénéficiaire']=='Turquie')|
        (d2a['Pays bénéficiaire']=='Thaïlande')|
        (d2a['Pays bénéficiaire']=='Tadjikistan')|
        (d2a['Pays bénéficiaire']=='Chine - RAS de Hong-Kong')|
        (d2a['Pays bénéficiaire']=='Sri Lanka')|
        (d2a['Pays bénéficiaire']=='Chine - RAS de Macao')|
        (d2a['Pays bénéficiaire']=='Chine, continentale')|
        (d2a['Pays bénéficiaire']=='Brunéi Darussalam')|
        (d2a['Pays bénéficiaire']=='Chine, Taiwan Province de')|
        (d2a['Pays bénéficiaire']=='Cambod2ae')|
        (d2a['Pays bénéficiaire']=='Timor-Leste')|
        (d2a['Pays bénéficiaire']=='République de Corée')|
        (d2a['Pays bénéficiaire']=='République démocratique populaire lao')|
        (d2a['Pays bénéficiaire']=='République populaire démocratique de Corée')|
        (d2a['Pays bénéficiaire']=='Philippines')|
        (d2a['Pays bénéficiaire']=='Pakistan')|
        (d2a['Pays bénéficiaire']=='Japon')|
        (d2a['Pays bénéficiaire']=='Indonésie')|
        (d2a['Pays bénéficiaire']=='Inde')|
        (d2a['Pays bénéficiaire']=='Népal')|
        (d2a['Pays bénéficiaire']=='Koweït')|
        (d2a['Pays bénéficiaire']=='Mongolie')|
        (d2a['Pays bénéficiaire']=='Iraq')|
        (d2a['Pays bénéficiaire']=='Iran (République islamique d\')')|
        (d2a['Pays bénéficiaire']=='Myanmar')|
        (d2a['Pays bénéficiaire']=='Kirghizistan')|
        (d2a['Pays bénéficiaire']=='Géorgie')|
        (d2a['Pays bénéficiaire']=='Maldives')|
        (d2a['Pays bénéficiaire']=='Malaisie')|
        (d2a['Pays bénéficiaire']=='Oman')|
        (d2a['Pays bénéficiaire']=='Ouzbékistan')|
        (d2a['Pays bénéficiaire']=='Israël')|
        (d2a['Pays bénéficiaire']=='Jordanie')|
        (d2a['Pays bénéficiaire']=='Afghanistan' )|
        (d2a['Pays bénéficiaire']=='Kazakhstan')|
        (d2a['Pays bénéficiaire']=='Liban')|
        (d2a['Pays bénéficiaire']=='Bhoutan')|
        (d2a['Pays bénéficiaire']=='Cambodge')|
        (d2a['Pays bénéficiaire']=='Palestine')|
        (d2a['Pays bénéficiaire']=='République arabe syrienne')
        
        
       ), 'Continent']='Asie'





d2a.loc[(
        (d2a['Pays bénéficiaire']=='États-Unis d\'Amérique' )|
        (d2a['Pays bénéficiaire']=='Mexique')|
        (d2a['Pays bénéficiaire']=='Canada')
        
        
       ), 'Continent']='Amerique du nord'

d2a.loc[(
        (d2a['Pays bénéficiaire']=='Antigua-et-Barbuda' )|
        (d2a['Pays bénéficiaire']=='Argentine')|
        (d2a['Pays bénéficiaire']=='Bahamas')|
        (d2a['Pays bénéficiaire']=='Barbade')|
        (d2a['Pays bénéficiaire']=='Uruguay')|
        (d2a['Pays bénéficiaire']=='Venezuela (République bolivarienne du)')|
        (d2a['Pays bénéficiaire']=='Équateur')|
        (d2a['Pays bénéficiaire']=='Belize')|
        (d2a['Pays bénéficiaire']=='Bermudes')|
        (d2a['Pays bénéficiaire']=='Bolivie (État plurinational de)')|
        (d2a['Pays bénéficiaire']=='Brésil')|
        (d2a['Pays bénéficiaire']=='Trinité-et-Tobago')|
        (d2a['Pays bénéficiaire']=='Chili')|
        (d2a['Pays bénéficiaire']=='Suriname')|
        (d2a['Pays bénéficiaire']=='Colombie')|
        (d2a['Pays bénéficiaire']=='Costa Rica')|
        (d2a['Pays bénéficiaire']=='Cuba')|
        (d2a['Pays bénéficiaire']=='Dominique')|
        (d2a['Pays bénéficiaire']=='El Salvador')|
        (d2a['Pays bénéficiaire']=='Saint-Kitts-et-Nevis')|
        (d2a['Pays bénéficiaire']=='Saint-Vincent-et-les Grenadines')|
        (d2a['Pays bénéficiaire']=='Sainte-Lucie')|
        (d2a['Pays bénéficiaire']=='République dominicaine')|
        (d2a['Pays bénéficiaire']=='Pérou')|
        (d2a['Pays bénéficiaire']=='Panama')|
        (d2a['Pays bénéficiaire']=='Paraguay')|
        (d2a['Pays bénéficiaire']=='Nicaragua')|
        (d2a['Pays bénéficiaire']=='Guatemala')|
        (d2a['Pays bénéficiaire']=='Grenade')|
        (d2a['Pays bénéficiaire']=='Honduras')|
        (d2a['Pays bénéficiaire']=='Jamaïque')|
        (d2a['Pays bénéficiaire']=='Guyana')|
        (d2a['Pays bénéficiaire']=='Haïti')
        
        
       ), 'Continent']='Amerique centrale, caribe et du sud'

d2a.loc[(
        (d2a['Pays bénéficiaire']=='Îles Salomon' )|
        (d2a['Pays bénéficiaire']=='Australie')|
        (d2a['Pays bénéficiaire']=='Vanuatu')|
        (d2a['Pays bénéficiaire']=='Samoa')|
        (d2a['Pays bénéficiaire']=='Fidji')|
        (d2a['Pays bénéficiaire']=='Kiribati')|
        (d2a['Pays bénéficiaire']=='Nouvelle-Zélande')|
        (d2a['Pays bénéficiaire']=='Nouvelle-Calédonie')|
        (d2a['Pays bénéficiaire']=='Polynésie française')
        
        
       ), 'Continent']='Oceanie'

#d2a[['Pays bénéficiaire', 'Continent']][ (d2a['Continent']=='Monde')]

# %%
del d2a['Année']

# %%
d2a.rename(columns={'Valeur': 'Aide en tonnes'}, inplace=True)

# %% [markdown]
# ## AIDE ALIMENTAIRE DEPUIS 2013

# %% [markdown]
# ### TOP 10 PAYS AVEC PLUS AIDE ALIMENTAIRE DEPUIS 2013

# %%
d2g=d2a.sort_values('Aide en tonnes', ascending = False).head(10)

# %%
d2g=d2g.reset_index()

# %%
d2a.sort_values('Aide en tonnes', ascending = False).head(10)
# Out:
#                    Pays bénéficiaire  Aide en tonnes Continent
# 50         République arabe syrienne         1858943      Asie
# 75                          Éthiopie         1381294   Afrique
# 70                             Yémen         1206484      Asie
# 61                     Soudan du Sud          695248   Afrique
# 60                            Soudan          669784   Afrique
# 30                             Kenya          552836   Afrique
# 3                         Bangladesh          348188      Asie
# 59                           Somalie          292678   Afrique
# 53  République démocratique du Congo          288502   Afrique
# 43                             Niger          276344   Afrique

# %%
gr.figure(figsize=(22, 5))
gr.bar(height=d2g['Aide en tonnes'], x=d2g['Pays bénéficiaire']) 
gr.show()

# %% [markdown]
# ## Le plus/le moins de disponibilité/habitant

# %%
cols= ['Zone','Population','Disponibilité alimentaire (Kcal/personne/jour)']

# %%
dg=d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition']).sum()#, 'Origine']).sum()

# %%
dg=dg.reset_index()

# %%
dg[cols].sort_values('Disponibilité alimentaire (Kcal/personne/jour)', ascending = False).head(10)
# Out:
#                       Zone  Population  \
# 11                Autriche     8819901
# 16                Belgique    11419748
# 159                Turquie    81116450
# 171  États-Unis d'Amérique   325084756
# 74                  Israël     8243848
# 72                 Irlande     4753279
# 75                  Italie    60673701
# 89              Luxembourg      591910
# 168                 Égypte    96442591
# 4                Allemagne    82658409
#
#      Disponibilité alimentaire (Kcal/personne/jour)
# 11                                           3770.0
# 16                                           3737.0
# 159                                          3708.0
# 171                                          3682.0
# 74                                           3610.0
# 72                                           3602.0
# 75                                           3578.0
# 89                                           3540.0
# 168                                          3518.0
# ...

# %%
dg[cols].sort_values('Disponibilité alimentaire (Kcal/personne/jour)', ascending = True).head(10)
# Out:
#                                            Zone  Population  \
# 128                   République centrafricaine     4596023
# 166                                      Zambie    16853599
# 91                                   Madagascar    25570512
# 0                                   Afghanistan    36296113
# 65                                        Haïti    10982366
# 133  République populaire démocratique de Corée    25429825
# 151                                       Tchad    15016753
# 167                                    Zimbabwe    14236595
# 114                                     Ouganda    41166588
# 154                                 Timor-Leste     1243258
#
#      Disponibilité alimentaire (Kcal/personne/jour)
# 128                                          1879.0
# 166                                          1924.0
# 91                                           2056.0
# 0                                            2087.0
# ...

# %%
dg=dg.reset_index()

# %%
#dg

# %%
#dg['Continent']='Monde'
dg.loc[(
        (dg['Zone']=='Afrique du Sud')|
        (dg['Zone']=='Angola')|
        (dg['Zone']=='Algérie')|
        (dg['Zone']=='Égypte')|
        (dg['Zone']=='Éthiopie')|
        (dg['Zone']=='Zambie')|
        (dg['Zone']=='Zimbabwe')|
        (dg['Zone']=='Tunisie')|
        (dg['Zone']=='Botswana')|
        (dg['Zone']=='Burkina Faso')|
        (dg['Zone']=='Cabo Verde')|
        (dg['Zone']=='Cameroun')|
        (dg['Zone']=='Togo')|
        (dg['Zone']=='Sénégal')|
        (dg['Zone']=='Bénin')|
        (dg['Zone']=='Congo')|
        (dg['Zone']=='Soudan')|
        (dg['Zone']=='Djibouti')|
        (dg['Zone']=='Sao Tomé-et-Principe')|
        (dg['Zone']=='Sierra Leone')|
        (dg['Zone']=='Tchad')|
        (dg['Zone']=='République-Unie de Tanzanie')|
        (dg['Zone']=='Côte d\'Ivoire')|
        (dg['Zone']=='Gabon')|
        (dg['Zone']=='Eswatini')|
        (dg['Zone']=='Gambie')|
        (dg['Zone']=='Ghana')|
        (dg['Zone']=='Rwanda')|
        (dg['Zone']=='République centrafricaine')|
        (dg['Zone']=='Guinée')|
        (dg['Zone']=='Mozambique')|
        (dg['Zone']=='Mauritanie')|
        (dg['Zone']=='Mali')|
        (dg['Zone']=='Kenya')|
        (dg['Zone']=='Nigéria')|
        (dg['Zone']=='Niger')|
        (dg['Zone']=='Maroc')|
        (dg['Zone']=='Malawi')|
        (dg['Zone']=='Maurice')|
        (dg['Zone']=='Ouganda')|
        (dg['Zone']=='Namibie')|
        (dg['Zone']=='Libéria')|
        (dg['Zone']=='Madagascar')|
        (dg['Zone']=='Guinée-Bissau')|
        (dg['Zone']=='Lesotho')
        
        
       ), 'Continent']='Afrique'

dg.loc[(
        (dg['Zone']=='Albanie' )|
        (dg['Zone']=='Allemagne')|
        (dg['Zone']=='Autriche')|
        (dg['Zone']=='Ukraine')|
        (dg['Zone']=='Bosnie-Herzégovine')|
        (dg['Zone']=='Belgique')|
        (dg['Zone']=='Tchéquie')|
        (dg['Zone']=='Bulgarie')|
        (dg['Zone']=='Suède')|
        (dg['Zone']=='Suisse')|
        (dg['Zone']=='Bélarus')|
        (dg['Zone']=='Slovaquie')|
        (dg['Zone']=='Slovénie')|
        (dg['Zone']=='Serbie')|
        (dg['Zone']=='Chypre')|
        (dg['Zone']=='Croatie')|
        (dg['Zone']=='Danemark')|
        (dg['Zone']=='Espagne')|
        (dg['Zone']=='Estonie')|
        (dg['Zone']=='France')|
        (dg['Zone']=='Finlande')|
        (dg['Zone']=='Fédération de Russie')|
    #Russie je vais le miser sur Europe pour des stats
        (dg['Zone']=='République de Moldova')|
        (dg['Zone']=='Grèce')|
        (dg['Zone']=='Roumanie')|
        (dg['Zone']=='Pologne')|
        (dg['Zone']=='Portugal')|
        (dg['Zone']=='Royaume-Uni de Grande-Bretagne et d\'Irlande du Nord')|
        (dg['Zone']=='Pays-Bas')|
        (dg['Zone']=='Lituanie')|
        (dg['Zone']=='Luxembourg')|
        (dg['Zone']=='Italie')|
        (dg['Zone']=='Lettonie')|
        (dg['Zone']=='Hongrie')|
        (dg['Zone']=='Monténégro')|
        (dg['Zone']=='Malte')|
        (dg['Zone']=='Norvège')|
        (dg['Zone']=='Macédoine du Nord')|
        (dg['Zone']=='Irlande')|
        (dg['Zone']=='Islande')
        
        
       ), 'Continent']='Europe'

dg.loc[(
        (dg['Zone']=='Émirats arabes unis' )|
        (dg['Zone']=='Arabie saoudite')|
        (dg['Zone']=='Arménie')|
        (dg['Zone']=='Viet Nam')|
        (dg['Zone']=='Yémen')|
        (dg['Zone']=='Azerbaïdjan')|
        (dg['Zone']=='Bangladesh')|
        (dg['Zone']=='Turkménistan')|
        (dg['Zone']=='Turquie')|
        (dg['Zone']=='Thaïlande')|
        (dg['Zone']=='Tadjikistan')|
        (dg['Zone']=='Chine - RAS de Hong-Kong')|
        (dg['Zone']=='Sri Lanka')|
        (dg['Zone']=='Chine - RAS de Macao')|
        (dg['Zone']=='Chine, continentale')|
        (dg['Zone']=='Brunéi Darussalam')|
        (dg['Zone']=='Chine, Taiwan Province de')|
        (dg['Zone']=='Cambodge')|
        (dg['Zone']=='Timor-Leste')|
        (dg['Zone']=='République de Corée')|
        (dg['Zone']=='République démocratique populaire lao')|
        (dg['Zone']=='République populaire démocratique de Corée')|
        (dg['Zone']=='Philippines')|
        (dg['Zone']=='Pakistan')|
        (dg['Zone']=='Japon')|
        (dg['Zone']=='Indonésie')|
        (dg['Zone']=='Inde')|
        (dg['Zone']=='Népal')|
        (dg['Zone']=='Koweït')|
        (dg['Zone']=='Mongolie')|
        (dg['Zone']=='Iraq')|
        (dg['Zone']=='Iran (République islamique d\')')|
        (dg['Zone']=='Myanmar')|
        (dg['Zone']=='Kirghizistan')|
        (dg['Zone']=='Géorgie')|
        (dg['Zone']=='Maldives')|
        (dg['Zone']=='Malaisie')|
        (dg['Zone']=='Oman')|
        (dg['Zone']=='Ouzbékistan')|
        (dg['Zone']=='Israël')|
        (dg['Zone']=='Jordanie')|
        (dg['Zone']=='Kazakhstan')|
        (dg['Zone']=='Liban')|
        (dg['Zone']=='Afghanistan')
        
        
       ), 'Continent']='Asie'





dg.loc[(
        (dg['Zone']=='États-Unis d\'Amérique' )|
        (dg['Zone']=='Mexique')|
        (dg['Zone']=='Canada')
        
        
       ), 'Continent']='Amerique du nord'

dg.loc[(
        (dg['Zone']=='Antigua-et-Barbuda' )|
        (dg['Zone']=='Argentine')|
        (dg['Zone']=='Bahamas')|
        (dg['Zone']=='Barbade')|
        (dg['Zone']=='Uruguay')|
        (dg['Zone']=='Venezuela (République bolivarienne du)')|
        (dg['Zone']=='Équateur')|
        (dg['Zone']=='Belize')|
        (dg['Zone']=='Bermudes')|
        (dg['Zone']=='Bolivie (État plurinational de)')|
        (dg['Zone']=='Brésil')|
        (dg['Zone']=='Trinité-et-Tobago')|
        (dg['Zone']=='Chili')|
        (dg['Zone']=='Suriname')|
        (dg['Zone']=='Colombie')|
        (dg['Zone']=='Costa Rica')|
        (dg['Zone']=='Cuba')|
        (dg['Zone']=='Dominique')|
        (dg['Zone']=='El Salvador')|
        (dg['Zone']=='Saint-Kitts-et-Nevis')|
        (dg['Zone']=='Saint-Vincent-et-les Grenadines')|
        (dg['Zone']=='Sainte-Lucie')|
        (dg['Zone']=='République dominicaine')|
        (dg['Zone']=='Pérou')|
        (dg['Zone']=='Panama')|
        (dg['Zone']=='Paraguay')|
        (dg['Zone']=='Nicaragua')|
        (dg['Zone']=='Guatemala')|
        (dg['Zone']=='Grenade')|
        (dg['Zone']=='Honduras')|
        (dg['Zone']=='Jamaïque')|
        (dg['Zone']=='Guyana')|
        (dg['Zone']=='Haïti')
        
        
       ), 'Continent']='Amerique centrale, caribe et du sud'

dg.loc[(
        (dg['Zone']=='Îles Salomon' )|
        (dg['Zone']=='Australie')|
        (dg['Zone']=='Vanuatu')|
        (dg['Zone']=='Samoa')|
        (dg['Zone']=='Fidji')|
        (dg['Zone']=='Kiribati')|
        (dg['Zone']=='Nouvelle-Zélande')|
        (dg['Zone']=='Nouvelle-Calédonie')|
        (dg['Zone']=='Polynésie française')
        
        
       ), 'Continent']='Oceanie'

#dg[['Zone', 'Continent']][ (dg['Continent']=='Monde')]

# %%
dg
# Out:
#      index                   Zone  Année  Population  Sous nutrition  \
# 0        0            Afghanistan   2017    36296113      10500000.0
# 1        1         Afrique du Sud   2017    57009756       3100000.0
# 2        2                Albanie   2017     2884169        100000.0
# 3        3                Algérie   2017    41389189       1300000.0
# 4        4              Allemagne   2017    82658409             0.0
# ..     ...                    ...    ...         ...             ...
# 169    169    Émirats arabes unis   2017     9487203        300000.0
# 170    170               Équateur   2017    16785361       1500000.0
# 171    171  États-Unis d'Amérique   2017   325084756             0.0
# 172    172               Éthiopie   2017   106399924      21100000.0
# 173    173           Îles Salomon   2017      636039             0.0
#
#      % Sous Nutrition  Aliments pour animaux  Autres Utilisations  \
# 0               28.93                  687.0                415.0
# ...

# %%
sous_total=dg.groupby(['Continent']).sum()['Sous nutrition'].sum()
dg=dg.groupby(['Continent']).sum()
dg['% Proportion Sous Nutrition dans le monde']=(dg['Sous nutrition']*100/sous_total).round(2)
dg['% Population en sous nutrition dans le continent']=(dg['Sous nutrition']/dg['Population']*100).round(2)
dg['% Proportion Population mundial']=(dg['Population']*100/pop).round(2)
dg['Personnes en Sous nutrition']=(dg['Sous nutrition'])
dg[[
    'Population', '% Proportion Population mundial',
    'Personnes en Sous nutrition','% Proportion Sous Nutrition dans le monde', 
     '% Population en sous nutrition dans le continent'
]].sort_values('% Population en sous nutrition dans le continent', ascending = False)
#Moyenne du monde 7.12 % population en sous nutrition
# Out:
#                                      Population  \
# Continent
# Afrique                              1112642897
# Asie                                 4485345034
# Amerique centrale, caribe et du sud   506666357
# Amerique du nord                      486594175
# Europe                                746072431
# Oceanie                                31948424
#
#                                      % Proportion Population mundial  \
# Continent
# Afrique                                                        14.74
# Asie                                                           59.42
# Amerique centrale, caribe et du sud                             6.71
# Amerique du nord                                                6.45
# Europe                                                          9.88
# Oceanie                                                         0.42
#
#                                      Personnes en Sous nutrition  \
# Continent
# ...

# %%
#d2a=d2a.reset_index()

# %% [markdown]
# # AIDE PAR CONTINENTS

# %%
aide_total=d2a.groupby(['Continent']).sum()['Aide en tonnes'].sum()

d2cont=d2a.groupby(['Continent']).sum()
d2cont['% Aide']=(d2cont['Aide en tonnes']*100/aide_total).round(2)
d2cont.sort_values('Aide en tonnes', ascending = False)
#dg.groupby(['Continent']).sum()
# Out:
#                                      Aide en tonnes  % Aide
# Continent
# Afrique                                     5984910   54.23
# Asie                                        4531243   41.06
# Amerique centrale, caribe et du sud          518946    4.70
# Oceanie                                         802    0.01

# %%
d2cont=d2cont.reset_index()

# %%
gr.pie(x=d2cont['Aide en tonnes'], labels=d2cont['Continent'] ,autopct='%.2f%%')
gr.show()

# %% [markdown]
# # Analyses de Julien

# %%
julien_csv = pd.read_csv ('fao_thai.csv')

# %%
#julien_csv.info()
#julien_csv.describe(include='all')

# %%
del (julien_csv['Code Domaine'], 
     julien_csv['Code Élément'], 
     julien_csv['Code Produit'], 
     julien_csv['Code année'], 
     julien_csv['Année'], 
     julien_csv['Code zone (FAO)'] )

# %%
julien_csv
# Out:
#                         Domaine       Zone  \
# 0   Bilans Alimentaires (2010-)  Thaïlande
# 1   Bilans Alimentaires (2010-)  Thaïlande
# 2   Bilans Alimentaires (2010-)  Thaïlande
# 3   Bilans Alimentaires (2010-)  Thaïlande
# 4   Bilans Alimentaires (2010-)  Thaïlande
# 5   Bilans Alimentaires (2010-)  Thaïlande
# 6   Bilans Alimentaires (2010-)  Thaïlande
# 7   Bilans Alimentaires (2010-)  Thaïlande
# 8   Bilans Alimentaires (2010-)  Thaïlande
# 9   Bilans Alimentaires (2010-)  Thaïlande
# 10  Bilans Alimentaires (2010-)  Thaïlande
#
#                                   Élément             Produit  \
# 0                              Production  Manioc et produits
# 1                 Importations - Quantité  Manioc et produits
# 2                      Variation de stock  Manioc et produits
# 3                 Exportations - Quantité  Manioc et produits
# 4                Disponibilité intérieure  Manioc et produits
# 5                   Aliments pour animaux  Manioc et produits
# ...

# %%
#julien_csv.iloc[0,5]

# %%
print( "Proportion de utilisation pour manger de manioc: ", ((julien_csv.iloc[10,5]*100/julien_csv.iloc[4,5]).round(2)))
# Out:
# Proportion de utilisation pour manger de manioc:  3.22

# %%
dgj=d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition','Produit']).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 dgj=d134.groupby(['Zone' , 'Année', 'Population', 'Sous nutrition', '% Sous Nutrition','Produit']).sum()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
# ...

# %%
dgj=dgj.reset_index()

# %%
dgj=dgj[dgj['Zone']=='Thaïlande']

# %%
#dgj.groupby['Zone'].sum()

# %%
dgjd=dgj.groupby(['Zone' ]).sum()

# %%
dgjd

# %%
dgjd['Exportations - Quantité'].sum()/dgjd['Disponibilité intérieure'].sum()

# %%
dgjd['Exportations - Quantité'].sum()

# %%
cols=dgjd.columns.to_list()

# %%
cols=[#'Année',
 #'Population',
 #'Sous nutrition',
 #'% Sous Nutrition',
    'Produit',
 'Aliments pour animaux',
 'Autres Utilisations',
 'Disponibilité alimentaire (Kcal/personne/jour)',
 'Disponibilité alimentaire en quantité (kg/personne/an)',
 'Disponibilité intérieure',
 'Exportations - Quantité',
 'Importations - Quantité',
 'Nourriture',
 'Pertes',
 'Production',
 'Semences',
 'Traitement',
 'Variation de stock',
 #'Disponibilité de matière grasse en quantité (kg/personne/an)',
 #'Disponibilité de protéines en quantité (kg/personne/an)',
 #'Dispo alimentaire kcal/personne/jour * Population'
]

# %%
dgj[cols][dgj['Produit']=='Manioc']

# %% [markdown]
# ### Proportion de utilisation pour exportation de manioc

# %%
print( "Proportion de utilisation pour exportation de manioc: ",
      (dgj['Exportations - Quantité'][dgj['Produit']=='Manioc'].sum()/dgj['Production'][dgj['Produit']=='Manioc'].sum()*100).round(2)
     )

# %%
#print( "Proportion de utilisation pour exportation de manioc: ", ((julien_csv.iloc[3,5]*100/julien_csv.iloc[0,5]).round(2)))

# %%
julien_csv2 = pd.read_csv ('fao_cer.csv')

# %%
del (julien_csv2['Code Domaine'], 
     julien_csv2['Code Élément'], 
     julien_csv2['Code Produit'], 
     julien_csv2['Code année'], 
     julien_csv2['Année'], 
     julien_csv2['Code zone (FAO)'] )

# %%
julien_csv2

# %%
j2=julien_csv2.groupby(['Élément', 'Produit']).sum().reset_index()

# %%
dispo_total=j2['Valeur'][j2['Élément']=='Disponibilité intérieure'].sum()
dispo_animaux=j2['Valeur'][j2['Élément']=='Aliments pour animaux'].sum()
dispo_nourriture=j2['Valeur'][j2['Élément']=='Nourriture'].sum()

# %%
len(j2['Produit'].unique())

# %%
len(d134['Produit'].unique())

# %%
liste=j2['Produit'].unique()

# %%
liste

# %%
djulien=d134[d134['Produit'].isin(liste)]

# %%
jcereal=j2['Valeur'][(j2['Produit']=='Céréales, Autres') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()

# %%
dispo_total,dispo_animaux, dispo_nourriture,jcereal

# %%
djuliendispo=djulien['Disponibilité intérieure'].sum()

# %%
djulien['Aliments pour animaux'].sum()*100/djulien['Disponibilité intérieure'].sum()

# %%
djulien['Nourriture'].sum()*100/djulien['Disponibilité intérieure'].sum()

# %%
print('Proportion disponibilité animaux:\n', (dispo_animaux*100/dispo_total).round(2), 
      '\n\nProportion disponibilité nourriture:\n', (dispo_nourriture*100/dispo_total).round(2) 
      
   ,'\n\nProportion disponibilité Céréales, Autres:   ', (jcereal*100/dispo_total).round(2) 
     ,  '\nProportion disponibilité Avoine:             ',
      (j2['Valeur'][(j2['Produit']=='Avoine') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2)  
      , '\nProportion disponibilité Blé et produits:   ',
      (j2['Valeur'][(j2['Produit']=='Blé et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
    , '\nProportion disponibilité Maïs et produits:  ',
      (j2['Valeur'][(j2['Produit']=='Maïs et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
    , '\nProportion disponibilité Millet et produits: ',
      (j2['Valeur'][(j2['Produit']=='Millet et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
      , '\nProportion disponibilité Orge et produits:   ',
      (j2['Valeur'][(j2['Produit']=='Orge et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
      , '\nProportion disponibilité Riz et produits:   ',
      (j2['Valeur'][(j2['Produit']=='Riz et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
      , '\nProportion disponibilité Seigle et produits: ',
      (j2['Valeur'][(j2['Produit']=='Seigle et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
      , '\nProportion disponibilité Sorgho et produits: ',
      (j2['Valeur'][(j2['Produit']=='Sorgho et produits') & (j2['Élément']=='Disponibilité intérieure' ) ].sum()*100/dispo_total).round(2) 
   
     
     
     
     )

# %%
#j2['Valeur'][(j2['Élément']=='Disponibilité intérieure' ) ].sum()

# %% [markdown]
# ### SOUS NUTRITION THAILANDE

# %%
dt=d134[d134['Zone']=='Thaïlande'].groupby(['Zone','% Sous Nutrition','Année', 'Population', 'Sous nutrition']).sum().reset_index()
print('\n\nSous nutrition en proportion en Thailande:  ', (dt['% Sous Nutrition'].sum().round(2)),'\n\n')

# %%
sous_total

# %%
#dp=d134.groupby(['Produit']).sum()
#del dp['Année'], dp['Population'],dp['Sous nutrition'],dp['% Sous Nutrition']

# %%
#proporcion susnutrition en tailande
#proportion de alimentation animal et nurriture pour chaque cereal en la somme total de cereal 
#en disponibilite interieure

#mortalite pour sous nutrition
#alimentation distribuee pour pays
