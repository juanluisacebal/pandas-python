# %% [markdown]
# # IMPORT

# %%
import warnings
warnings.simplefilter("ignore")

import pandas as pd
erp = pd.read_excel('erp.xlsx')
liaison = pd.read_excel('liaison.xlsx')
web = pd.read_excel('web.xlsx')

import matplotlib.pyplot as plt 
import seaborn as sb
import numpy as np
from scipy.stats import zscore

# %% [markdown]
# # DISPLAY **

# %%
display(erp)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]

# %%
display(liaison)
# Out:
#      product_id   id_web
# 0          3847    15298
# 1          3849    15296
# 2          3850    15300
# 3          4032    19814
# 4          4039    19815
# ..          ...      ...
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# [825 rows x 2 columns]

# %%
display(web)
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# 1                0.0          6.0    taxable        NaN          2.0
# 2                0.0          0.0    taxable        NaN          2.0
# 3                0.0          0.0    taxable        NaN          2.0
# 4                0.0          3.0    taxable        NaN          2.0
# ...              ...          ...        ...        ...          ...
# 1508             0.0          5.0        NaN        NaN          2.0
# 1509             0.0          0.0        NaN        NaN          2.0
# 1510             0.0          0.0        NaN        NaN          2.0
# 1511             0.0          0.0        NaN        NaN          2.0
# 1512             0.0          0.0        NaN        NaN          2.0
#
#                post_date  ...  \
# 0    2018-06-01 13:53:46  ...
# 1    2018-02-08 12:58:52  ...
# 2    2018-02-08 13:49:41  ...
# 3    2018-02-08 14:08:36  ...
# 4    2018-02-09 14:01:05  ...
# ...                  ...  ...
# 1508 2020-04-25 13:22:38  ...
# 1509 2020-05-02 14:53:40  ...
# 1510 2020-05-02 15:00:54  ...
# 1511 2020-06-09 15:42:04  ...
# 1512 2020-07-20 11:00:00  ...
#
#                                               post_name       post_modified  \
# 0                                bon-cadeau-de-25-euros 2018-06-01 14:13:57
# 1           pierre-jean-villa-saint-joseph-preface-2018 2019-12-30 09:30:29
# 2             pierre-jean-villa-saint-joseph-tilde-2017 2019-12-21 09:00:17
# 3     pierre-jean-villa-croze-hermitage-accroche-coe... 2020-06-26 18:15:03
# 4                     pierre-jean-villa-igp-gamine-2018 2020-01-04 16:36:01
# ...                                                 ...                 ...
# 1508                    mouthes-le-bihan-aime-chai-2015 2020-08-26 17:35:03
# 1509         camin-larredya-jurancon-sec-la-virada-2018 2020-08-26 17:35:02
# 1510             jamet-cote-rotie-fructus-voluptas-2018 2020-08-14 18:15:03
# 1511     clos-du-mont-olivet-chateauneuf-du-pape-2007-2 2020-07-20 17:09:06
# 1512  domaine-saint-nicolas-fiefs-vendeens-blanc-les... 2020-08-13 10:45:03
#
#        post_modified_gmt post_content_filtered post_parent  \
# 0    2018-06-01 12:13:57                   NaN         0.0
# 1    2019-12-30 08:30:29                   NaN         0.0
# 2    2019-12-21 08:00:17                   NaN         0.0
# 3    2020-06-26 16:15:03                   NaN         0.0
# 4    2020-01-04 15:36:01                   NaN         0.0
# ...                  ...                   ...         ...
# 1508 2020-08-26 15:35:03                   NaN         0.0
# 1509 2020-08-26 15:35:02                   NaN         0.0
# 1510 2020-08-14 16:15:03                   NaN         0.0
# 1511 2020-07-20 15:09:06                   NaN         0.0
# 1512 2020-08-13 08:45:03                   NaN         0.0
#
#                                                    guid menu_order  \
# 0     https://www.bottle-neck.fr/?post_type=product&...        0.0
# 1     https://www.bottle-neck.fr/?post_type=product&...        0.0
# 2     https://www.bottle-neck.fr/?post_type=product&...        0.0
# 3     https://www.bottle-neck.fr/?post_type=product&...        0.0
# 4     https://www.bottle-neck.fr/?post_type=product&...        0.0
# ...                                                 ...        ...
# 1508  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 1509  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 1510  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 1511  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 1512  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
#
#        post_type post_mime_type comment_count
# 0        product            NaN           0.0
# 1        product            NaN           0.0
# 2        product            NaN           0.0
# 3        product            NaN           0.0
# 4        product            NaN           0.0
# ...          ...            ...           ...
# 1508  attachment     image/jpeg           0.0
# 1509  attachment     image/jpeg           0.0
# 1510  attachment     image/jpeg           0.0
# 1511  attachment     image/jpeg           0.0
# 1512  attachment     image/jpeg           0.0
#
# [1513 rows x 28 columns]

# %% [markdown]
# # DESCRIBE ET INFO **

# %% [markdown]
# ## ERP

# %%
erp.describe(include='all')
# Out:
#          product_id  onsale_web       price  stock_quantity stock_status
# count    825.000000  825.000000  825.000000      825.000000          825
# unique          NaN         NaN         NaN             NaN            2
# top             NaN         NaN         NaN             NaN      instock
# freq            NaN         NaN         NaN             NaN          638
# mean    5162.597576    0.869091   32.415636       26.496970          NaN
# std      902.644635    0.337506   26.795849       45.892422          NaN
# min     3847.000000    0.000000    5.200000        0.000000          NaN
# 25%     4348.000000    1.000000   14.600000        1.000000          NaN
# 50%     4907.000000    1.000000   24.400000       11.000000          NaN
# 75%     5805.000000    1.000000   42.000000       34.000000          NaN
# max     7338.000000    1.000000  225.000000      578.000000          NaN

# %%
erp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 32.4+ KB

# %% [markdown]
# ## LIAISON

# %%
liaison.describe()#include='all')
# Out:
#         product_id
# count   825.000000
# mean   5162.597576
# std     902.644635
# min    3847.000000
# 25%    4348.000000
# 50%    4907.000000
# 75%    5805.000000
# max    7338.000000

# %% [markdown]
# #### identificar las lineas 825-734= xx y mostrarlas y 734-714 cifras de negocios total y por producto en proporcion, distribucion de precios, valores aberrantes

# %%
liaison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  825 non-null    int64
#  1   id_web      734 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 13.0+ KB

# %% [markdown]
# ## WEB

# %%
web.describe(include='all', datetime_is_numeric=True)
# Out:
#                         sku  virtual  downloadable  rating_count  \
# count                  1428   1513.0        1513.0        1513.0
# unique                  714      NaN           NaN           NaN
# top     bon-cadeau-25-euros      NaN           NaN           NaN
# freq                      2      NaN           NaN           NaN
# mean                    NaN      0.0           0.0           0.0
# min                     NaN      0.0           0.0           0.0
# 25%                     NaN      0.0           0.0           0.0
# 50%                     NaN      0.0           0.0           0.0
# 75%                     NaN      0.0           0.0           0.0
# max                     NaN      0.0           0.0           0.0
# std                     NaN      0.0           0.0           0.0
#
#         average_rating  total_sales tax_status  tax_class  post_author  \
# count           1430.0  1430.000000        716        0.0  1430.000000
# unique             NaN          NaN          1        NaN          NaN
# top                NaN          NaN    taxable        NaN          NaN
# freq               NaN          NaN        716        NaN          NaN
# mean               0.0     4.006993        NaN        NaN     1.998601
# min                0.0     0.000000        NaN        NaN     1.000000
# 25%                0.0     0.000000        NaN        NaN     2.000000
# 50%                0.0     1.000000        NaN        NaN     2.000000
# 75%                0.0     4.000000        NaN        NaN     2.000000
# max                0.0    96.000000        NaN        NaN     2.000000
# std                0.0     8.510559        NaN        NaN     0.037385
#
#                             post_date  ...               post_name  \
# count                            1430  ...                    1430
# unique                            NaN  ...                     716
# top                               NaN  ...  bon-cadeau-de-25-euros
# freq                              NaN  ...                       2
# mean    2018-08-22 03:22:17.090908928  ...                     NaN
# min               2018-02-08 12:58:52  ...                     NaN
# 25%        2018-02-27 20:01:12.500000  ...                     NaN
# 50%               2018-04-19 14:56:05  ...                     NaN
# 75%               2019-01-31 14:35:47  ...                     NaN
# max               2020-07-20 11:00:00  ...                     NaN
# std                               NaN  ...                     NaN
#
#                         post_modified              post_modified_gmt  \
# count                            1430                           1430
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2020-06-20 13:59:29.781818368  2020-06-20 12:06:02.509090816
# min               2018-02-20 15:19:23            2018-02-20 14:19:23
# 25%     2020-06-18 10:45:05.249999872  2020-06-18 08:45:05.249999872
# 50%               2020-08-04 09:30:06            2020-08-04 07:30:06
# 75%               2020-08-25 10:32:32            2020-08-25 08:32:32
# max               2020-08-27 18:55:03            2020-08-27 16:55:03
# std                               NaN                            NaN
#
#        post_content_filtered post_parent  \
# count                    0.0      1430.0
# unique                   NaN         NaN
# top                      NaN         NaN
# freq                     NaN         NaN
# mean                     NaN         0.0
# min                      NaN         0.0
# 25%                      NaN         0.0
# 50%                      NaN         0.0
# 75%                      NaN         0.0
# max                      NaN         0.0
# std                      NaN         0.0
#
#                                                      guid menu_order  \
# count                                                1430     1430.0
# unique                                               1430        NaN
# top     https://www.bottle-neck.fr/?post_type=product&...        NaN
# freq                                                    1        NaN
# mean                                                  NaN        0.0
# min                                                   NaN        0.0
# 25%                                                   NaN        0.0
# 50%                                                   NaN        0.0
# 75%                                                   NaN        0.0
# max                                                   NaN        0.0
# std                                                   NaN        0.0
#
#         post_type post_mime_type comment_count
# count        1430            714        1430.0
# unique          2              1           NaN
# top       product     image/jpeg           NaN
# freq          716            714           NaN
# mean          NaN            NaN           0.0
# min           NaN            NaN           0.0
# 25%           NaN            NaN           0.0
# 50%           NaN            NaN           0.0
# 75%           NaN            NaN           0.0
# max           NaN            NaN           0.0
# std           NaN            NaN           0.0
#
# [11 rows x 28 columns]

# %%
web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1428 non-null   object
#  1   virtual                1513 non-null   int64
#  2   downloadable           1513 non-null   int64
#  3   rating_count           1513 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   datetime64[ns]
#  10  post_date_gmt          1430 non-null   datetime64[ns]
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
#  13  post_excerpt           716 non-null    object
#  14  post_status            1430 non-null   object
#  15  comment_status         1430 non-null   object
#  16  ping_status            1430 non-null   object
#  17  post_password          0 non-null      float64
#  18  post_name              1430 non-null   object
#  19  post_modified          1430 non-null   datetime64[ns]
#  20  post_modified_gmt      1430 non-null   datetime64[ns]
#  21  post_content_filtered  0 non-null      float64
#  22  post_parent            1430 non-null   float64
#  23  guid                   1430 non-null   object
#  24  menu_order             1430 non-null   float64
#  25  post_type              1430 non-null   object
#  26  post_mime_type         714 non-null    object
#  27  comment_count          1430 non-null   float64
# dtypes: datetime64[ns](4), float64(10), int64(3), object(11)
# memory usage: 331.1+ KB

# %% [markdown]
# # SHAPE ET DUPLICATED **

# %% [markdown]
# ## SHAPE

# %%
erp.shape
# Out:
# (825, 5)

# %%
liaison.shape
# Out:
# (825, 2)

# %%
web.shape
# Out:
# (1513, 28)

# %% [markdown]
# ## DUPLICATED

# %%
erp.duplicated().count()
# Out:
# 825

# %%
liaison.duplicated().count()
# Out:
# 825

# %%
web.duplicated().count()
# Out:
# 1513

# %% [markdown]
# ## NUNIQUE

# %%
erp.nunique()
# Out:
# product_id        825
# onsale_web          2
# price             381
# stock_quantity    128
# stock_status        2
# dtype: int64

# %%
liaison.nunique()
# Out:
# product_id    825
# id_web        734
# dtype: int64

# %%
web.nunique()
# Out:
# sku                       714
# virtual                     1
# downloadable                1
# rating_count                1
# average_rating              1
# total_sales                41
# tax_status                  1
# tax_class                   0
# post_author                 2
# post_date                 716
# post_date_gmt             716
# post_content                0
# post_title                713
# post_excerpt              679
# post_status                 1
# comment_status              1
# ping_status                 1
# post_password               0
# post_name                 716
# post_modified             589
# post_modified_gmt         589
# post_content_filtered       0
# post_parent                 1
# guid                     1430
# menu_order                  1
# post_type                   2
# post_mime_type              1
# comment_count               1
# dtype: int64

# %%
### PRIMARY KEY: sku (web) - id_web (liaison)

# %% [markdown]
# # FILLNA **

# %%
liaison['product_id'].isnull().sum()
# Out:
# 0

# %%
liaison['id_web'].isnull().sum()
# Out:
# 91

# %%
#liaison.drop(0)
#liaison.drop(liaison[liaison['id_web'] == 0].index , inplace=True)

# %%
liaison.dropna(inplace=True)

# %%
len(liaison['product_id'].unique())
# Out:
# 734

# %%
len(liaison['id_web'].unique())
# Out:
# 734

# %%
len(erp['product_id'].unique())
# Out:
# 825

# %%
erp.count()
# Out:
# product_id        825
# onsale_web        825
# price             825
# stock_quantity    825
# stock_status      825
# dtype: int64

# %%
web.rename(columns={'sku': 'id_web'}, inplace=True)

# %%
columns=web.columns.tolist()

# %%
columns=['id_web',
 #'virtual',
 #'downloadable',
 #'rating_count',
 #'average_rating',
 'total_sales',
 'tax_status',
 #'tax_class',
 #'post_author',
 #'post_date',
 'post_date_gmt',
 #'post_content',
 'post_title',
 'post_excerpt',
 ##'post_status',
 ##'comment_status',
 ##'ping_status',
 #'post_password',
 'post_name',
 #'post_modified',
 'post_modified_gmt',
 #'post_content_filtered',
 #'post_parent',
 'guid',
 #'menu_order',
 'post_type',
 'post_mime_type',
 #'comment_count'
        ]

# %%
web=web[columns]

# %%
web[web['id_web']==16135]
# Out:
#      id_web  total_sales tax_status       post_date_gmt  \
# 762   16135          5.0    taxable 2020-04-25 11:22:38
# 1508  16135          5.0        NaN 2020-04-25 11:22:38
#
#                                             post_title  \
# 762   Mouthes Le Bihan Côtes de Duras L'Aimé Chai 2015
# 1508  Mouthes Le Bihan Côtes de Duras L'Aimé Chai 2015
#
#                                            post_excerpt  \
# 762   Belle robe jeune à dominante rubis soutenue. N...
# 1508                                                NaN
#
#                             post_name   post_modified_gmt  \
# 762   mouthes-le-bihan-aime-chai-2015 2020-08-26 15:35:03
# 1508  mouthes-le-bihan-aime-chai-2015 2020-08-26 15:35:03
#
#                                                    guid   post_type  \
# 762   https://www.bottle-neck.fr/?post_type=product&...     product
# 1508  https://www.bottle-neck.fr/wp-content/uploads/...  attachment
#
#      post_mime_type
# 762             NaN
# 1508     image/jpeg

# %%
web=web.groupby(['id_web','tax_status','post_date_gmt','post_excerpt','post_title'], dropna=True).mean()

# %%
web
# Out:
#                                                                                                                                                           total_sales
# id_web              tax_status post_date_gmt       post_excerpt                                       post_title
# 38                  taxable    2018-04-18 10:25:58 Ce Crémant est vif et délicat, gourmand et croq... Emile Boeckel Crémant Brut Blanc de Blancs                 38.0
# 41                  taxable    2018-04-14 10:01:43 Les eaux de vie naissent d'une subtile alchimie... Marcel Windholtz Eau de Vie de Marc de Gewurztr...          0.0
# 304                 taxable    2018-02-13 11:57:44 Le nez, ouvert et expressif, évoque les fruits ... Champagne Gosset Grande Réserve                            40.0
# 523                 taxable    2019-04-06 13:25:58 Issus des meilleurs crus de Grande et de Petite... Cognac Normandin Mercier VFC                                0.0
# 531                 taxable    2018-07-18 13:58:02 Cuvée bien équilibrée à la fois vive et souple,... Champagne Petit Lebrun &amp; Fils Blanc de Blan...         13.0
# ...                                                                                                                                                               ...
# 19820               taxable    2018-11-26 09:54:29 <div id="wrapper">\n<div id="container-wrapper"... Tempier Bandol Migoua 2017                                  0.0
# 19821               taxable    2018-11-26 09:56:30 <div id="wrapper">\n<div id="container-wrapper"... Tempier Bandol Tourtine 2017                                0.0
# 19822               taxable    2018-11-26 09:59:10 <div id="wrapper">\n<div id="container-wrapper"... Tempier Bandol Cabassaou 2017                               0.0
# 13127-1             taxable    2020-06-09 13:42:04 Nez gracieux, très élégant avec une touche flor... Clos du Mont-Olivet Châteauneuf-du-Pape 2007                0.0
# bon-cadeau-25-euros taxable    2018-06-01 11:53:46 <span style="color: #a85253;"><strong>Parlons p... Bon cadeau de 25€                                          10.0
#
# [714 rows x 1 columns]

# %%
web=web.reset_index()

# %%
web
# Out:
#                   id_web tax_status       post_date_gmt  \
# 0                     38    taxable 2018-04-18 10:25:58
# 1                     41    taxable 2018-04-14 10:01:43
# 2                    304    taxable 2018-02-13 11:57:44
# 3                    523    taxable 2019-04-06 13:25:58
# 4                    531    taxable 2018-07-18 13:58:02
# ..                   ...        ...                 ...
# 709                19820    taxable 2018-11-26 09:54:29
# 710                19821    taxable 2018-11-26 09:56:30
# 711                19822    taxable 2018-11-26 09:59:10
# 712              13127-1    taxable 2020-06-09 13:42:04
# 713  bon-cadeau-25-euros    taxable 2018-06-01 11:53:46
#
#                                           post_excerpt  \
# 0    Ce Crémant est vif et délicat, gourmand et cro...
# 1    Les eaux de vie naissent d'une subtile alchimi...
# 2    Le nez, ouvert et expressif, évoque les fruits...
# 3    Issus des meilleurs crus de Grande et de Petit...
# 4    Cuvée bien équilibrée à la fois vive et souple...
# ..                                                 ...
# 709  <div id="wrapper">\n<div id="container-wrapper...
# 710  <div id="wrapper">\n<div id="container-wrapper...
# 711  <div id="wrapper">\n<div id="container-wrapper...
# 712  Nez gracieux, très élégant avec une touche flo...
# 713  <span style="color: #a85253;"><strong>Parlons ...
#
#                                             post_title  total_sales
# 0           Emile Boeckel Crémant Brut Blanc de Blancs         38.0
# 1    Marcel Windholtz Eau de Vie de Marc de Gewurzt...          0.0
# 2                      Champagne Gosset Grande Réserve         40.0
# 3                         Cognac Normandin Mercier VFC          0.0
# 4    Champagne Petit Lebrun &amp; Fils Blanc de Bla...         13.0
# ..                                                 ...          ...
# 709                         Tempier Bandol Migoua 2017          0.0
# 710                       Tempier Bandol Tourtine 2017          0.0
# 711                      Tempier Bandol Cabassaou 2017          0.0
# 712       Clos du Mont-Olivet Châteauneuf-du-Pape 2007          0.0
# 713                                  Bon cadeau de 25€         10.0
#
# [714 rows x 6 columns]

# %%
web[web['id_web'] == 15298]
# Out:
#     id_web tax_status       post_date_gmt  \
# 325  15298    taxable 2018-02-08 11:58:52
#
#                                           post_excerpt  \
# 325  Il exhale un nez subtil, racé avec du poivre f...
#
#                                       post_title  total_sales
# 325  Pierre Jean Villa Saint-Joseph Préface 2018          6.0

# %%
web['tax_status'].dropna(inplace=True)

# %%
web
# Out:
#                   id_web tax_status       post_date_gmt  \
# 0                     38    taxable 2018-04-18 10:25:58
# 1                     41    taxable 2018-04-14 10:01:43
# 2                    304    taxable 2018-02-13 11:57:44
# 3                    523    taxable 2019-04-06 13:25:58
# 4                    531    taxable 2018-07-18 13:58:02
# ..                   ...        ...                 ...
# 709                19820    taxable 2018-11-26 09:54:29
# 710                19821    taxable 2018-11-26 09:56:30
# 711                19822    taxable 2018-11-26 09:59:10
# 712              13127-1    taxable 2020-06-09 13:42:04
# 713  bon-cadeau-25-euros    taxable 2018-06-01 11:53:46
#
#                                           post_excerpt  \
# 0    Ce Crémant est vif et délicat, gourmand et cro...
# 1    Les eaux de vie naissent d'une subtile alchimi...
# 2    Le nez, ouvert et expressif, évoque les fruits...
# 3    Issus des meilleurs crus de Grande et de Petit...
# 4    Cuvée bien équilibrée à la fois vive et souple...
# ..                                                 ...
# 709  <div id="wrapper">\n<div id="container-wrapper...
# 710  <div id="wrapper">\n<div id="container-wrapper...
# 711  <div id="wrapper">\n<div id="container-wrapper...
# 712  Nez gracieux, très élégant avec une touche flo...
# 713  <span style="color: #a85253;"><strong>Parlons ...
#
#                                             post_title  total_sales
# 0           Emile Boeckel Crémant Brut Blanc de Blancs         38.0
# 1    Marcel Windholtz Eau de Vie de Marc de Gewurzt...          0.0
# 2                      Champagne Gosset Grande Réserve         40.0
# 3                         Cognac Normandin Mercier VFC          0.0
# 4    Champagne Petit Lebrun &amp; Fils Blanc de Bla...         13.0
# ..                                                 ...          ...
# 709                         Tempier Bandol Migoua 2017          0.0
# 710                       Tempier Bandol Tourtine 2017          0.0
# 711                      Tempier Bandol Cabassaou 2017          0.0
# 712       Clos du Mont-Olivet Châteauneuf-du-Pape 2007          0.0
# 713                                  Bon cadeau de 25€         10.0
#
# [714 rows x 6 columns]

# %% [markdown]
# # MERGE **

# %%
el= pd.merge(erp, liaison , on='product_id', how='left')

# %%
display(el)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status   id_web
# 0          3847           1   24.2               0   outofstock    15298
# 1          3849           1   34.3               0   outofstock    15296
# 2          3850           1   20.8               0   outofstock    15300
# 3          4032           1   14.1               0   outofstock    19814
# 4          4039           1   46.0               0   outofstock    19815
# ..          ...         ...    ...             ...          ...      ...
# 820        7203           0   45.0              30      instock      NaN
# 821        7204           0   45.0               9      instock      NaN
# 822        7247           1   54.8              23      instock  13127-1
# 823        7329           0   26.5              14      instock  14680-1
# 824        7338           1   16.3              45      instock    16230
#
# [825 rows x 6 columns]

# %%
el.describe(include='all')
# Out:
#          product_id  onsale_web       price  stock_quantity stock_status  \
# count    825.000000  825.000000  825.000000      825.000000          825
# unique          NaN         NaN         NaN             NaN            2
# top             NaN         NaN         NaN             NaN      instock
# freq            NaN         NaN         NaN             NaN          638
# mean    5162.597576    0.869091   32.415636       26.496970          NaN
# std      902.644635    0.337506   26.795849       45.892422          NaN
# min     3847.000000    0.000000    5.200000        0.000000          NaN
# 25%     4348.000000    1.000000   14.600000        1.000000          NaN
# 50%     4907.000000    1.000000   24.400000       11.000000          NaN
# 75%     5805.000000    1.000000   42.000000       34.000000          NaN
# max     7338.000000    1.000000  225.000000      578.000000          NaN
#
#          id_web
# count     734.0
# unique    734.0
# top     15298.0
# freq        1.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
el[el['stock_status']=='outofstock'].count()
# Out:
# product_id        187
# onsale_web        187
# price             187
# stock_quantity    187
# stock_status      187
# id_web            158
# dtype: int64

# %%
el[el['stock_status']=='instock'].count()
# Out:
# product_id        638
# onsale_web        638
# price             638
# stock_quantity    638
# stock_status      638
# id_web            576
# dtype: int64

# %%
elw = pd.merge(el, web, how='right', on='id_web')

# %%
elw.describe(include='all', datetime_is_numeric=True)
# Out:
#          product_id  onsale_web       price  stock_quantity stock_status  \
# count    714.000000       714.0  714.000000      714.000000          714
# unique          NaN         NaN         NaN             NaN            2
# top             NaN         NaN         NaN             NaN      instock
# freq            NaN         NaN         NaN             NaN          574
# mean    5032.557423         1.0   32.493137       28.746499          NaN
# min     3847.000000         1.0    5.200000        0.000000          NaN
# 25%     4280.250000         1.0   14.100000        2.000000          NaN
# 50%     4796.000000         1.0   23.550000       12.000000          NaN
# 75%     5710.500000         1.0   42.175000       35.000000          NaN
# max     7338.000000         1.0  225.000000      578.000000          NaN
# std      790.510878         0.0   27.810525       48.012608          NaN
#
#         id_web tax_status                  post_date_gmt  \
# count    714.0        714                            714
# unique   714.0          1                            NaN
# top       38.0    taxable                            NaN
# freq       1.0        714                            NaN
# mean       NaN        NaN  2018-08-22 02:29:08.581232640
# min        NaN        NaN            2018-02-08 11:58:52
# 25%        NaN        NaN     2018-02-27 19:01:12.500000
# 50%        NaN        NaN            2018-04-19 12:52:10
# 75%        NaN        NaN            2019-01-31 13:35:47
# max        NaN        NaN            2020-07-20 09:00:00
# std        NaN        NaN                            NaN
#
#                                              post_excerpt  \
# count                                                 714
# unique                                                677
# top     Les eaux de vie naissent d'une subtile alchimi...
# freq                                                   12
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                                                post_title  total_sales
# count                                                 714   714.000000
# unique                                                711          NaN
# top     Marc Colin Et Fils Chassagne-Montrachet Blanc ...          NaN
# freq                                                    2          NaN
# mean                                                  NaN     4.012605
# min                                                   NaN     0.000000
# 25%                                                   NaN     0.000000
# 50%                                                   NaN     1.000000
# 75%                                                   NaN     4.000000
# max                                                   NaN    96.000000
# std                                                   NaN     8.518183

# %%
elw['product_id'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 709    False
# 710    False
# 711    False
# 712    False
# 713    False
# Name: product_id, Length: 714, dtype: bool

# %%
elw['product_id'].dropna(inplace=True)

# %%
elw[elw['onsale_web']==0]
# Out:
# Empty DataFrame
# Columns: [product_id, onsale_web, price, stock_quantity, stock_status, id_web, tax_status, post_date_gmt, post_excerpt, post_title, total_sales]
# Index: []

# %%
print ( len(elw['id_web'].unique())
,
len(elw['product_id'].unique())
      )
# Out:
# 714 714

# %% [markdown]
# # ANALYSE DE DONNEES **

# %% [markdown]
# ## 714 PRODUITS **

# %%
elw.groupby(['id_web']  ).mean()
# Out:
#                      product_id  onsale_web  price  stock_quantity  \
# id_web
# 38                       4729.0         1.0    8.6           151.0
# 41                       4634.0         1.0   41.0             4.0
# 304                      4141.0         1.0   39.0             1.0
# 523                      5932.0         1.0   59.9             3.0
# 531                      5047.0         1.0   22.5           129.0
# ...                         ...         ...    ...             ...
# 19820                    5561.0         1.0   58.0             0.0
# 19821                    5563.0         1.0   58.0             0.0
# 19822                    5565.0         1.0   92.0             0.0
# 13127-1                  7247.0         1.0   54.8            23.0
# bon-cadeau-25-euros      4954.0         1.0   25.0             0.0
#
#                      total_sales
# id_web
# 38                          38.0
# 41                           0.0
# 304                         40.0
# 523                          0.0
# 531                         13.0
# ...                          ...
# 19820                        0.0
# 19821                        0.0
# 19822                        0.0
# 13127-1                      0.0
# bon-cadeau-25-euros         10.0
#
# [714 rows x 5 columns]

# %% [markdown]
# ## SALES=0 ET STOCK>0 = 256

# %%
elw[ (elw['total_sales']==0.0) & (elw['stock_quantity']>0)    ].sort_values('price')
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 195        6129           1    5.2              30      instock  14570
# 176        5777           1    5.7             132      instock  14338
# 673        4198           1    5.8             105      instock  16322
# 610        4755           1    7.4              97      instock  16132
# 177        4739           1    7.4              50      instock  14366
# ..          ...         ...    ...             ...          ...    ...
# 225        5917           1  122.0               4      instock  14775
# 245        5612           1  124.8              12      instock  14915
# 33         4406           1  157.0               3      instock   7819
# 300        5767           1  175.0              12      instock  15185
# 198        5001           1  217.5              20      instock  14581
#
#     tax_status       post_date_gmt  \
# 195    taxable 2019-06-28 16:01:06
# 176    taxable 2019-03-15 09:13:30
# 673    taxable 2018-02-15 12:51:32
# 610    taxable 2018-04-18 19:55:53
# 177    taxable 2018-04-18 19:00:55
# ..         ...                 ...
# 225    taxable 2019-04-04 14:49:37
# 245    taxable 2019-01-15 14:30:49
# 33     taxable 2018-03-22 10:42:48
# 300    taxable 2019-03-13 13:43:22
# 198    taxable 2018-07-17 07:45:39
#
#                                           post_excerpt  \
# 195  Nez Séduisant et puissant. Bouquet de fleurs j...
# 176  <span style="float: none; background-color: tr...
# 673  Belle complexité aromatique alliant fruits rou...
# 610  C'est un vin de soif, léger et épicé. Le Groll...
# 177  Dans sa robe pourpre, signe d'une jeunesse fri...
# ..                                                 ...
# 225  710 bouteilles, 17 ans d'âge.\n\n<span title="...
# 245  Né sur un sol marno-gréseux, ce Furstentum est...
# 33   Eau-de-Vie distillée à partir de raisins de Gr...
# 300  <div>Ce vin provient de vignes âgées de 50 ans...
# 198  Robe cerise chatoyante. Un nez de fruits rouge...
#
#                                             post_title  total_sales
# 195  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...          0.0
# 176           Maurel Pays d'Oc Cabernet-Sauvignon 2017          0.0
# 673  Moulin de Gassac IGP Pays d'Hérault Guilhem Ro...          0.0
# 610   Domaine de Montgilet Vin de France Grolleau 2019          0.0
# 177           Jean-Paul Brun Beaujolais Le Ronsay 2016          0.0
# ..                                                 ...          ...
# 225  Wemyss Malts Single Cask Scotch Whisky Choc 'n...          0.0
# 245  Domaine Weinbach Gewurztraminer Grand Cru Furs...          0.0
# 33   Cognac Frapin Château de Fontpinot 1989 20 Ans...          0.0
# 300                Camille Giroud Clos de Vougeot 2016          0.0
# 198     David Duband Charmes-Chambertin Grand Cru 2014          0.0
#
# [256 rows x 11 columns]

# %% [markdown]
# ## NUAGE DE POINTS STOCK/PRICE **

# %%
k=elw[ (elw['total_sales']==0.0) & (elw['stock_quantity']>0)]
plt.figure(figsize=(10,10))
sb.scatterplot(data=k, x='price', y='stock_quantity')
plt.grid()
plt.show()

# %% [markdown]
# ## STOCK=0 ET STOCK_STATUS=INSTOCK = 1

# %%
elw[(elw['stock_quantity']==0) & (elw['stock_status']=='instock')].sort_values('price')
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status  \
# 713        4954           1   25.0               0      instock
#
#                   id_web tax_status       post_date_gmt  \
# 713  bon-cadeau-25-euros    taxable 2018-06-01 11:53:46
#
#                                           post_excerpt         post_title  \
# 713  <span style="color: #a85253;"><strong>Parlons ...  Bon cadeau de 25€
#
#      total_sales
# 713         10.0

# %% [markdown]
# ## PRICES PRODUITS **

# %%
elw['price'].hist(bins=40) #DISTRIBUTION
# Out:
# <AxesSubplot:>

# %%
elw['price'].describe()
# Out:
# count    714.000000
# mean      32.493137
# std       27.810525
# min        5.200000
# 25%       14.100000
# 50%       23.550000
# 75%       42.175000
# max      225.000000
# Name: price, dtype: float64

# %% [markdown]
# ### 307 P. ENTRE 0 et 20

# %%
elw['price'][(elw['price']>0) & (elw['price']<=20)].count()
# Out:
# 307

# %% [markdown]
# ### 212 P. ENTRE 20 et 40

# %%
elw['price'][(elw['price']>20) & (elw['price']<=40)].count()
# Out:
# 212

# %% [markdown]
# ### 115 P. ENTRE 40 et 60

# %%
elw['price'][(elw['price']>40) & (elw['price']<=60)].count()
# Out:
# 115

# %% [markdown]
# ### 46 P. ENTRE 60 et 80

# %%
elw['price'][(elw['price']>60) & (elw['price']<=80)].count()
# Out:
# 46

# %% [markdown]
# ### 9 P. ENTRE 80 et 100

# %%
elw['price'][(elw['price']>80) & (elw['price']<=100)].count()
# Out:
# 9

# %% [markdown]
# ### 307 P. ENTRE 100 et 150

# %%
elw['price'][(elw['price']>100) & (elw['price']<=150)].count()
# Out:
# 19

# %% [markdown]
# ### 4 P. ENTRE 150 et 200

# %%
elw['price'][(elw['price']>150) & (elw['price']<=200)].count()
# Out:
# 4

# %% [markdown]
# ### 2 P. ENTRE 200 et 240

# %%
elw['price'][(elw['price']>200) & (elw['price']<=240)].count()
# Out:
# 2

# %%
#elw[(elw['price']>200) & (elw['price']<=240)]

# %% [markdown]
# ## TOP VENTES **

# %%
topventes=elw.sort_values('total_sales', ascending = False).head(5)

# %%
topventes
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 32         4334           1   49.0               0   outofstock   7818
# 16         4144           1   49.0              11      instock   1662
# 680        4068           1   16.6             157      instock  16416
# 663        4200           1    5.8             190      instock  16295
# 634        4172           1    5.7             167      instock  16210
#
#     tax_status       post_date_gmt  \
# 32     taxable 2018-03-01 13:02:44
# 16     taxable 2018-02-13 12:17:25
# 680    taxable 2018-02-12 12:42:28
# 663    taxable 2018-02-15 13:05:06
# 634    taxable 2018-02-14 15:54:33
#
#                                           post_excerpt  \
# 32   La bulle fine et presente se dirige vers la su...
# 16   Le nez exprime sans détour la fraise, dans sa ...
# 680  Avec ses arômes de cassis, de myrtille, de cer...
# 663  Rosé très agréable, intense, floral et minéral...
# 634  Un très joli petit chardonnay qui nous révèle ...
#
#                                             post_title  total_sales
# 32              Champagne Gosset Grand Blanc de Blancs         96.0
# 16                         Champagne Gosset Grand Rosé         87.0
# 680  Gilles Robin Crozes-Hermitage Rouge Papillon 2019         62.0
# 663  Moulin de Gassac IGP Pays d'Hérault Guilhem Ro...         46.0
# 634                   Maurel Pays d'Oc Chardonnay 2019         43.0

# %%
plt.figure(figsize=(26, 10))
plt.bar(height=topventes['total_sales'], x=topventes['post_title']) 
plt.show()

# %% [markdown]
# ## (MOINS SALES) 1 SALES = 87 PRODUITS

# %%
moins_sales=elw[elw['total_sales']==1].sort_values('total_sales', ascending = True)

# %%
moins_sales
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 15         4150           1   59.0              17      instock   1366
# 523        5522           1   48.4              10      instock  15861
# 516        4646           1   21.5              34      instock  15848
# 515        6926           1   49.9              24      instock  15845
# 501        6632           1   52.7               2      instock  15794
# ..          ...         ...    ...             ...          ...    ...
# 218        5700           1   44.5               0   outofstock  14736
# 216        4241           1    8.9               7      instock  14725
# 186        4162           1   14.3              26      instock  14474
# 297        5772           1   29.7              47      instock  15180
# 686        4298           1   23.2              36      instock  16501
#
#     tax_status       post_date_gmt  \
# 15     taxable 2018-02-13 12:45:31
# 523    taxable 2018-10-31 12:52:29
# 516    taxable 2018-04-17 07:23:13
# 515    taxable 2020-04-25 10:43:23
# 501    taxable 2020-01-23 11:06:12
# ..         ...                 ...
# 218    taxable 2019-01-31 10:58:26
# 216    taxable 2018-02-20 09:07:09
# 186    taxable 2018-02-14 13:53:20
# 297    taxable 2019-03-13 14:08:45
# 686    taxable 2018-02-28 13:53:17
#
#                                           post_excerpt  \
# 15   A l’œil, la robe brillante séduit par sa belle...
# 523  L'Angéline séduit par sa trame ronde et souple...
# 516  Le Clos Guillot est un vin raffiné. Ses arômes...
# 515  Velouté, profond, racé, beaucoup de sève. Très...
# 501  <span title="">Des fruits rouges des bois en b...
# ..                                                 ...
# 218  Fruit d'une histoire et d'un héritage familial...
# 216  Avec cette cuvée, Les Frères Parcé ont voulu r...
# 186  Ce vin présente un nez plein de fruits, avec d...
# 297  <div>Ce vin provient de vignes situées dans de...
# 686  Ce vin se veut accessible mais d’une belle com...
#
#                                             post_title  total_sales
# 15        Champagne Mailly Grand Cru Intemporelle 2010          1.0
# 523      Domaine Chambeyron Côte Rôtie L'Angéline 2017          1.0
# 516   Bernard Baudry Chinon Rouge Le Clos Guillot 2017          1.0
# 515    Château Jean Faure Saint-Emilion Grand Cru 2016          1.0
# 501  Weingut Besson-Strasser Zürich Pinot Noir Chlo...          1.0
# ..                                                 ...          ...
# 218    Gilles Robin Crozes-Hermitage Rouge "1920" 2016          1.0
# 216  Parcé Frères IGP Côtes Catalanes Hommage à Fer...          1.0
# 186  Domino Romano Ribera Del Duero Camino Romano 2016          1.0
# 297                 Camille Giroud Santenay Rouge 2016          1.0
# 686        Domaine de La Tour Du Bon Bandol Rouge 2018          1.0
#
# [87 rows x 11 columns]

# %% [markdown]
# ## VENTES PAR POST DU PRODUIT

# %% [markdown]
# ### VENTES DE 2018 = 2370 DIVISÉ EN 3 ANNEES= 790 EN 507 PRODUITS

# %%
elw['total_sales'][(elw['post_date_gmt']>='2018-01-01') & (elw['post_date_gmt']<'2019-01-01')].sum()/3
# Out:
# 790.0

# %%
elw['total_sales'][(elw['post_date_gmt']>='2018-01-01') & (elw['post_date_gmt']<'2019-01-01')].count()
# Out:
# 507

# %% [markdown]
# ### VENTES 2019 = 458 DIVISÉ EN 2 ANNEES= 229 EN 164 PRODUITS

# %%
elw['total_sales'][(elw['post_date_gmt']>='2019-01-01') & (elw['post_date_gmt']<'2020-01-01')].sum()/2
# Out:
# 229.0

# %%
elw['total_sales'][(elw['post_date_gmt']>='2019-01-01') & (elw['post_date_gmt']<'2020-01-01')].count()
# Out:
# 164

# %% [markdown]
# ### VENTES 2020 = 37 EN 43 PRODUITS

# %%
elw['total_sales'][(elw['post_date_gmt']>='2020-01-01') & (elw['post_date_gmt']<'2021-01-01')].sum()
# Out:
# 37.0

# %%
elw['total_sales'][(elw['post_date_gmt']>='2020-01-01') & (elw['post_date_gmt']<'2021-01-01')].count()
# Out:
# 43

# %% [markdown]
# # CHIFRES D'AFFAIRES **

# %% [markdown]
# ## TOTAL SALES & CHIFFRES HISTOGRAM **

# %%
elw['Chiffre d\'affaires']=elw['price']*elw['total_sales']

# %%
elw['Chiffre d\'affaires'].hist()
# Out:
# <AxesSubplot:>

# %%
elw['total_sales'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## CHIFFRE D'AFFAIRES/DATE POST NUAGE P. **

# %%
plt.figure(figsize=(12,5))
sb.scatterplot(data=elw, 
               x='post_date_gmt',
               y='price', 
               sizes=(3, 150),
               legend='brief',
               size='Chiffre d\'affaires')
plt.grid()
plt.show()

# %%
elw_col=elw.columns.tolist()

# %%
elw_col=['product_id',
'post_title',
 #'onsale_web',
 'price',
 'stock_quantity',
 #'stock_status',
 #'id_web',
 #'tax_status',
 #'post_date_gmt',
 #'post_excerpt',
 #'total_sales',
 'Chiffre d\'affaires',
 #'% Cifres afaires'
        ]

# %% [markdown]
# ## TOP CHIFFRE D'AFFAIRES EN EUROS

# %%
elw[elw_col].sort_values('Chiffre d\'affaires', ascending = False).head(10)
# Out:
#      product_id                                         post_title  price  \
# 32         4334             Champagne Gosset Grand Blanc de Blancs   49.0
# 16         4144                        Champagne Gosset Grand Rosé   49.0
# 24         4402                               Cognac Frapin VIP XO  176.0
# 55         4142              Champagne Gosset Grand Millésime 2006   53.0
# 2          4141                    Champagne Gosset Grande Réserve   39.0
# 79         4355     Champagne Egly-Ouriet Grand Cru Blanc de Noirs  126.5
# 548        4352     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 639        4153   Elian Daros Côtes du Marmandais Clos Baquey 2015   29.0
# 703        6206           Domaine Giudicelli Patrimonio Blanc 2019   25.2
# 680        4068  Gilles Robin Crozes-Hermitage Rouge Papillon 2019   16.6
#
#      stock_quantity  Chiffre d'affaires
# 32                0              4704.0
# 16               11              4263.0
# 24                8              2288.0
# 55                8              1590.0
# 2                 1              1560.0
# 79                2              1391.5
# 548               0              1125.0
# 639               0              1044.0
# 703             120              1033.2
# 680             157              1029.2

# %%
chiffres_affaires=elw['Chiffre d\'affaires'].sum()

# %% [markdown]
# ### CHIFFRE D'AFFAIRES TOTAL

# %%
chiffres_affaires
# Out:
# 70568.6

# %%
elw['% Chiffre d\'affaires']=(elw['Chiffre d\'affaires']/chiffres_affaires*100).round(2)

# %%
elw_col=['product_id',
'post_title',
 #'onsale_web',
 'price',
 'stock_quantity',
 #'stock_status',
 #'id_web',
 #'tax_status',
 #'post_date_gmt',
 #'post_excerpt',
 #'total_sales',
 #'Chiffre d\'affaires',
 '% Chiffre d\'affaires']

# %% [markdown]
# ## CHIFFRES D'AFFAIRES EN PROPORTION DU TOTAL **

# %%
elw[elw_col].sort_values('% Chiffre d\'affaires', ascending = False).head(10)
# Out:
#      product_id                                         post_title  price  \
# 32         4334             Champagne Gosset Grand Blanc de Blancs   49.0
# 16         4144                        Champagne Gosset Grand Rosé   49.0
# 24         4402                               Cognac Frapin VIP XO  176.0
# 55         4142              Champagne Gosset Grand Millésime 2006   53.0
# 2          4141                    Champagne Gosset Grande Réserve   39.0
# 79         4355     Champagne Egly-Ouriet Grand Cru Blanc de Noirs  126.5
# 548        4352     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 639        4153   Elian Daros Côtes du Marmandais Clos Baquey 2015   29.0
# 703        6206           Domaine Giudicelli Patrimonio Blanc 2019   25.2
# 680        4068  Gilles Robin Crozes-Hermitage Rouge Papillon 2019   16.6
#
#      stock_quantity  % Chiffre d'affaires
# 32                0                  6.67
# 16               11                  6.04
# 24                8                  3.24
# 55                8                  2.25
# 2                 1                  2.21
# 79                2                  1.97
# 548               0                  1.59
# 639               0                  1.48
# 703             120                  1.46
# 680             157                  1.46

# %%
elw_g=elw.sort_values('% Chiffre d\'affaires', ascending = False).head(10)
plt.figure(figsize=(9, 9))
#gr.bar
plt.style.use('ggplot')
plt.barh(elw_g['post_title'] ,elw_g['Chiffre d\'affaires'] ) 
plt.title('TOP 10 de chiffres d\'affaires')
plt.xlabel('Chiffre d\'affaires')
plt.show()

#BOX PLOT

# %% [markdown]
# # ANALYSE DE VALEURS ABERRANTES **

# %% [markdown]
# ## INTERVALLES INTERQUARTILES **

# %% [markdown]
# ### PRICE **

# %%
q3, q1 = np.percentile (elw['price'], [75, 25])
iqr = q3 - q1
iqr
# Out:
# 28.075000000000003

# %%
q3
# Out:
# 42.175000000000004

# %%
q1
# Out:
# 14.1

# %%
(q3-q1)/2
# Out:
# 14.037500000000001

# %%
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)

# %%
low
# Out:
# -28.012500000000003

# %%
high
# Out:
# 84.28750000000001

# %% [markdown]
# ### OUTLIERS INTERVALLES INTERQUARTILES **

# %%
elw[['price']][elw['price']>high].sort_values('price', ascending = False)
# Out:
#      price
# 548  225.0
# 198  217.5
# 258  191.3
# 24   176.0
# 300  175.0
# 33   157.0
# 168  137.0
# 246  135.0
# 79   126.5
# 245  124.8
# 225  122.0
# 270  121.0
# 269  121.0
# 279  116.4
# 154  115.0
# 86   115.0
# 223  114.0
# 147  112.0
# 88   109.6
# 22   108.5
# 199  105.6
# 87   105.0
# 54   105.0
# 23   104.0
# 229  102.3
# 356  100.0
# 53    99.0
# 224   93.0
# 711   92.0
# 56    88.4
# 146   86.8
# 140   85.6

# %%
elw['price'].mean()
# Out:
# 32.493137254902

# %%
elw['price'].std() #equart type
# Out:
# 27.810524922323708

# %%
elw['price'].describe()
# Out:
# count    714.000000
# mean      32.493137
# std       27.810525
# min        5.200000
# 25%       14.100000
# 50%       23.550000
# 75%       42.175000
# max      225.000000
# Name: price, dtype: float64

# %%
boxplot = elw.boxplot(column=['price']
,figsize=(10,10))

# %%
elw[ (elw['Chiffre d\'affaires'] >= q3) ]
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status  \
# 0          4729           1    8.6             151      instock
# 2          4141           1   39.0               1      instock
# 4          5047           1   22.5             129      instock
# 6          4630           1   62.4               3      instock
# 9          4633           1   52.4               2      instock
# ..          ...         ...    ...             ...          ...
# 703        6206           1   25.2             120      instock
# 705        4965           1    7.1             203      instock
# 706        4032           1   14.1               0   outofstock
# 708        4054           1   71.6               0   outofstock
# 713        4954           1   25.0               0      instock
#
#                   id_web tax_status       post_date_gmt  \
# 0                     38    taxable 2018-04-18 10:25:58
# 2                    304    taxable 2018-02-13 11:57:44
# 4                    531    taxable 2018-07-18 13:58:02
# 6                    793    taxable 2018-04-14 09:52:20
# 9                    804    taxable 2018-04-14 09:59:32
# ..                   ...        ...                 ...
# 703                16580    taxable 2019-07-24 07:31:48
# 705                16586    taxable 2018-06-02 07:35:14
# 706                19814    taxable 2018-02-09 13:01:05
# 708                19816    taxable 2018-02-12 10:25:39
# 713  bon-cadeau-25-euros    taxable 2018-06-01 11:53:46
#
#                                           post_excerpt  \
# 0    Ce Crémant est vif et délicat, gourmand et cro...
# 2    Le nez, ouvert et expressif, évoque les fruits...
# 4    Cuvée bien équilibrée à la fois vive et souple...
# 6    Les eaux de vie naissent d'une subtile alchimi...
# 9    Les eaux de vie naissent d'une subtile alchimi...
# ..                                                 ...
# 703  Ce Patrimonio Blanc signé Muriel Giudicelli no...
# 705  <div id="wrapper">\n<div id="container-wrapper...
# 706  Gamine représente tout le fruité et la gourman...
# 708  Fleuron du domaine, élaboré uniquement lors de...
# 713  <span style="color: #a85253;"><strong>Parlons ...
#
#                                             post_title  total_sales  \
# 0           Emile Boeckel Crémant Brut Blanc de Blancs         38.0
# 2                      Champagne Gosset Grande Réserve         40.0
# 4    Champagne Petit Lebrun &amp; Fils Blanc de Bla...         13.0
# 6                 Marcel Windholtz Eau de Vie de Coing          4.0
# 9    Marcel Windholtz Eau de Vie de Mirabelle d'Als...          3.0
# ..                                                 ...          ...
# 703           Domaine Giudicelli Patrimonio Blanc 2019         41.0
# 705               Château Turcaud Entre-Deux-Mers 2019         26.0
# 706  Pierre Jean Villa IGP Collines Rhodaniennes Ga...          3.0
# 708  Clos du Mont-Olivet Châteauneuf-du-Pape Cuvée ...         10.0
# 713                                  Bon cadeau de 25€         10.0
#
#      Chiffre d'affaires  % Chiffre d'affaires
# 0                 326.8                  0.46
# 2                1560.0                  2.21
# 4                 292.5                  0.41
# 6                 249.6                  0.35
# 9                 157.2                  0.22
# ..                  ...                   ...
# 703              1033.2                  1.46
# 705               184.6                  0.26
# 706                42.3                  0.06
# 708               716.0                  1.01
# 713               250.0                  0.35
#
# [275 rows x 13 columns]

# %%
 elw [(elw['Chiffre d\'affaires']<=q1)]
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 1          4634           1   41.0               4      instock       41
# 3          5932           1   59.9               3      instock      523
# 5          4631           1   76.8               3      instock      791
# 7          4635           1   62.4               3      instock      798
# 8          4628           1   39.6               2      instock      802
# ..          ...         ...    ...             ...          ...      ...
# 707        4039           1   46.0               0   outofstock    19815
# 709        5561           1   58.0               0   outofstock    19820
# 710        5563           1   58.0               0   outofstock    19821
# 711        5565           1   92.0               0   outofstock    19822
# 712        7247           1   54.8              23      instock  13127-1
#
#     tax_status       post_date_gmt  \
# 1      taxable 2018-04-14 10:01:43
# 3      taxable 2019-04-06 13:25:58
# 5      taxable 2018-04-14 09:54:47
# 7      taxable 2018-04-14 10:05:09
# 8      taxable 2018-04-14 09:48:19
# ..         ...                 ...
# 707    taxable 2018-02-12 08:04:37
# 709    taxable 2018-11-26 09:54:29
# 710    taxable 2018-11-26 09:56:30
# 711    taxable 2018-11-26 09:59:10
# 712    taxable 2020-06-09 13:42:04
#
#                                           post_excerpt  \
# 1    Les eaux de vie naissent d'une subtile alchimi...
# 3    Issus des meilleurs crus de Grande et de Petit...
# 5    Les eaux de vie naissent d'une subtile alchimi...
# 7    Les eaux de vie naissent d'une subtile alchimi...
# 8    Les eaux de vie naissent d'une subtile alchimi...
# ..                                                 ...
# 707  Le côte rôtie Carmina monte en puissance mais ...
# 709  <div id="wrapper">\n<div id="container-wrapper...
# 710  <div id="wrapper">\n<div id="container-wrapper...
# 711  <div id="wrapper">\n<div id="container-wrapper...
# 712  Nez gracieux, très élégant avec une touche flo...
#
#                                             post_title  total_sales  \
# 1    Marcel Windholtz Eau de Vie de Marc de Gewurzt...          0.0
# 3                         Cognac Normandin Mercier VFC          0.0
# 5          Marcel Windholtz Eau de Vie de Baie de Houx          0.0
# 7    Marcel Windholtz Eau de Vie de Kirsch d'Alsace...          0.0
# 8        Marcel Windholtz Eau de Vie de Marc de Muscat          0.0
# ..                                                 ...          ...
# 707          Pierre Jean Villa Côte Rôtie Carmina 2017          0.0
# 709                         Tempier Bandol Migoua 2017          0.0
# 710                       Tempier Bandol Tourtine 2017          0.0
# 711                      Tempier Bandol Cabassaou 2017          0.0
# 712       Clos du Mont-Olivet Châteauneuf-du-Pape 2007          0.0
#
#      Chiffre d'affaires  % Chiffre d'affaires
# 1                   0.0                   0.0
# 3                   0.0                   0.0
# 5                   0.0                   0.0
# 7                   0.0                   0.0
# 8                   0.0                   0.0
# ..                  ...                   ...
# 707                 0.0                   0.0
# 709                 0.0                   0.0
# 710                 0.0                   0.0
# 711                 0.0                   0.0
# 712                 0.0                   0.0
#
# [354 rows x 13 columns]

# %% [markdown]
# ## NUAGE DE POINTS **

# %% [markdown]
# ### CIFRES AFAIRES **

# %%
elw_out=elw[ (elw['price']>high) | (elw['price']<low) ]
elw_in=elw[(elw['price']<=high) & (elw['price']>=low)]
elw_out['Outlier / Inliers']= 'Outlier'
elw_in['Outlier / Inliers']= 'Inlier'
elw_oi= pd.merge(elw_in, elw_out, how='outer')#, on='product_id')


#elw['Outlier / Inliers'][elw['price']>high]='Outlier'

# %%
plt.scatter(elw_out.index,elw_out['price'])
plt.scatter(elw_in.index,elw_in['price'])

# %%
elw['Outlier / Inliers']=''
elw['Outlier / Inliers'][(elw['price']>high)]='Outlier'
elw['Outlier / Inliers'][elw['price']<=high]='Inlier'

# %%
plt.figure(figsize=(12,5))
sb.scatterplot(data=elw, x=elw.index , y='price', 
               sizes=(3, 150),
               legend='brief',
               hue='Outlier / Inliers',size='Chiffre d\'affaires')
#x='Cifres afaires', y='post_date_gmt')#, figsize=(10,10))
plt.grid()
plt.show()

# %%
#k=elw[ (elw['Cifres afaires']<=q1) | (elw['Cifres afaires']>=q3)]
#gr.figure(figsize=(10,10))
#sb.scatterplot(data=k, x='Cifres afaires', y='post_date_gmt')
#gr.grid()
#gr.show()

# %% [markdown]
# ## ZSCORE - PRICE **

# %%
numeric_cols = elw.select_dtypes(include=[np.number]).columns

elw_z=elw[numeric_cols].apply(zscore)

# %%
elw_z
# Out:
#      product_id  onsale_web     price  stock_quantity  total_sales  \
# 0     -0.384271         NaN -0.859742        2.548064     3.992779
# 1     -0.504530         NaN  0.306101       -0.515778    -0.471394
# 2     -1.128615         NaN  0.234135       -0.578305     4.227735
# 3      1.138597         NaN  0.986176       -0.536620    -0.471394
# 4      0.018283         NaN -0.359581        2.089530     1.055823
# ..          ...         ...       ...             ...          ...
# 709    0.668951         NaN  0.917809       -0.599148    -0.471394
# 710    0.671483         NaN  0.917809       -0.599148    -0.471394
# 711    0.674015         NaN  2.141225       -0.599148    -0.471394
# 712    2.803244         NaN  0.802664       -0.119771    -0.471394
# 713   -0.099445         NaN -0.269624       -0.599148     0.703388
#
#      Chiffre d'affaires  % Chiffre d'affaires
# 0              0.741421              0.734513
# 1             -0.321448             -0.321350
# 2              4.752225              4.751383
# 3             -0.321448             -0.321350
# 4              0.629865              0.619746
# ..                  ...                   ...
# 709           -0.321448             -0.321350
# 710           -0.321448             -0.321350
# 711           -0.321448             -0.321350
# 712           -0.321448             -0.321350
# 713            0.491640              0.482024
#
# [714 rows x 7 columns]

# %%
elw_zscore=pd.merge(elw, elw_z, left_index=True, right_index=True)

# %%
zcolumns=elw_zscore.columns.tolist()

# %%
zcolumns=[
    'product_id_x',
 'onsale_web_x',
 'price_x',
 'stock_quantity_x',
 'stock_status',
 'id_web',
 'tax_status',
 'post_date_gmt',
 'post_excerpt',
 'post_title',
 'total_sales_x',
 'Chiffre d\'affaires_x',
 '% Chiffre d\'affaires_x',
# 'product_id_y',
 #'onsale_web_y',
 'price_y',
# 'stock_quantity_y',
# 'total_sales_y',
 'Chiffre d\'affaires_y',
 #'% Chiffre d\'affaires_y'
]

# %%
elw_zscore[zcolumns].sort_values('price_y', ascending = False).head(10)
# Out:
#      product_id_x  onsale_web_x  price_x  stock_quantity_x stock_status  \
# 548          4352             1    225.0                 0   outofstock
# 198          5001             1    217.5                20      instock
# 258          5892             1    191.3                10      instock
# 24           4402             1    176.0                 8      instock
# 300          5767             1    175.0                12      instock
# 33           4406             1    157.0                 3      instock
# 168          4904             1    137.0                13      instock
# 246          6126             1    135.0                10      instock
# 79           4355             1    126.5                 2      instock
# 245          5612             1    124.8                12      instock
#
#     id_web tax_status       post_date_gmt  \
# 548  15940    taxable 2018-03-02 09:30:04
# 198  14581    taxable 2018-07-17 07:45:39
# 258  14983    taxable 2019-03-28 09:21:36
# 24    3510    taxable 2018-03-22 10:21:05
# 300  15185    taxable 2019-03-13 13:43:22
# 33    7819    taxable 2018-03-22 10:42:48
# 168  14220    taxable 2018-05-15 08:23:41
# 246  14923    taxable 2019-06-28 15:22:27
# 79   12589    taxable 2018-03-02 09:46:10
# 245  14915    taxable 2019-01-15 14:30:49
#
#                                           post_excerpt  \
# 548  Issu d’un assemblage de 70% de Pinot Noir du g...
# 198  Robe cerise chatoyante. Un nez de fruits rouge...
# 258  Cet Ambonnay évoque les grands Pinots Noirs de...
# 24   La cuvée VIP XO à été enrichie d’eaux-de-vie t...
# 300  <div>Ce vin provient de vignes âgées de 50 ans...
# 33   Eau-de-Vie distillée à partir de raisins de Gr...
# 168  Ce Corton Charlemagne éblouit par son assise, ...
# 246  Une robe somptueuse a la teinte jaune pâle eti...
# 79   Le Blanc de Noirs représente le meilleur du sa...
# 245  Né sur un sol marno-gréseux, ce Furstentum est...
#
#                                             post_title  total_sales_x  \
# 548     Champagne Egly-Ouriet Grand Cru Millésimé 2008            5.0
# 198     David Duband Charmes-Chambertin Grand Cru 2014            0.0
# 258  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...            3.0
# 24                                Cognac Frapin VIP XO           13.0
# 300                Camille Giroud Clos de Vougeot 2016            0.0
# 33   Cognac Frapin Château de Fontpinot 1989 20 Ans...            0.0
# 168  Domaine Des Croix Corton Charlemagne Grand Cru...            5.0
# 246             Champagne Gosset Célébris Vintage 2007            2.0
# 79      Champagne Egly-Ouriet Grand Cru Blanc de Noirs           11.0
# 245  Domaine Weinbach Gewurztraminer Grand Cru Furs...            0.0
#
#      Chiffre d'affaires_x  % Chiffre d'affaires_x   price_y  \
# 548                1125.0                    1.59  6.926939
# 198                   0.0                    0.00  6.657068
# 258                 573.9                    0.81  5.714318
# 24                 2288.0                    3.24  5.163781
# 300                   0.0                    0.00  5.127798
# 33                    0.0                    0.00  4.480108
# 168                 685.0                    0.97  3.760451
# 246                 270.0                    0.38  3.688486
# 79                 1391.5                    1.97  3.382632
# 245                   0.0                    0.00  3.321461
#
#      Chiffre d'affaires_y
# 548              3.337451
# 198             -0.321448
# 258              1.545078
# 24               7.119939
# 300             -0.321448
# 33              -0.321448
# 168              1.906415
# 246              0.556687
# 79               4.204203
# 245             -0.321448

# %%
elw_zscore[zcolumns][elw_zscore['price_y']>4]
# Out:
#      product_id_x  onsale_web_x  price_x  stock_quantity_x stock_status  \
# 24           4402             1    176.0                 8      instock
# 33           4406             1    157.0                 3      instock
# 198          5001             1    217.5                20      instock
# 258          5892             1    191.3                10      instock
# 300          5767             1    175.0                12      instock
# 548          4352             1    225.0                 0   outofstock
#
#     id_web tax_status       post_date_gmt  \
# 24    3510    taxable 2018-03-22 10:21:05
# 33    7819    taxable 2018-03-22 10:42:48
# 198  14581    taxable 2018-07-17 07:45:39
# 258  14983    taxable 2019-03-28 09:21:36
# 300  15185    taxable 2019-03-13 13:43:22
# 548  15940    taxable 2018-03-02 09:30:04
#
#                                           post_excerpt  \
# 24   La cuvée VIP XO à été enrichie d’eaux-de-vie t...
# 33   Eau-de-Vie distillée à partir de raisins de Gr...
# 198  Robe cerise chatoyante. Un nez de fruits rouge...
# 258  Cet Ambonnay évoque les grands Pinots Noirs de...
# 300  <div>Ce vin provient de vignes âgées de 50 ans...
# 548  Issu d’un assemblage de 70% de Pinot Noir du g...
#
#                                             post_title  total_sales_x  \
# 24                                Cognac Frapin VIP XO           13.0
# 33   Cognac Frapin Château de Fontpinot 1989 20 Ans...            0.0
# 198     David Duband Charmes-Chambertin Grand Cru 2014            0.0
# 258  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...            3.0
# 300                Camille Giroud Clos de Vougeot 2016            0.0
# 548     Champagne Egly-Ouriet Grand Cru Millésimé 2008            5.0
#
#      Chiffre d'affaires_x  % Chiffre d'affaires_x   price_y  \
# 24                 2288.0                    3.24  5.163781
# 33                    0.0                    0.00  4.480108
# 198                   0.0                    0.00  6.657068
# 258                 573.9                    0.81  5.714318
# 300                   0.0                    0.00  5.127798
# 548                1125.0                    1.59  6.926939
#
#      Chiffre d'affaires_y
# 24               7.119939
# 33              -0.321448
# 198             -0.321448
# 258              1.545078
# 300             -0.321448
# 548              3.337451

# %%
elw_zscore['price_x'][elw_zscore['price_y']>4]
# Out:
# 24     176.0
# 33     157.0
# 198    217.5
# 258    191.3
# 300    175.0
# 548    225.0
# Name: price_x, dtype: float64

# %%
elw_zscore[zcolumns][elw_zscore['price_y']>3].count()
# Out:
# product_id_x              14
# onsale_web_x              14
# price_x                   14
# stock_quantity_x          14
# stock_status              14
# id_web                    14
# tax_status                14
# post_date_gmt             14
# post_excerpt              14
# post_title                14
# total_sales_x             14
# Chiffre d'affaires_x      14
# % Chiffre d'affaires_x    14
# price_y                   14
# Chiffre d'affaires_y      14
# dtype: int64

# %% [markdown]
# ### VALEURS ABERRANTES **

# %%
(elw_zscore[['price_x']][elw_zscore['price_y']>2]).sort_values('price_x', ascending = False)
# Out:
#      price_x
# 548    225.0
# 198    217.5
# 258    191.3
# 24     176.0
# 300    175.0
# 33     157.0
# 168    137.0
# 246    135.0
# 79     126.5
# 245    124.8
# 225    122.0
# 269    121.0
# 270    121.0
# 279    116.4
# 86     115.0
# 154    115.0
# 223    114.0
# 147    112.0
# 88     109.6
# 22     108.5
# 199    105.6
# 87     105.0
# 54     105.0
# 23     104.0
# 229    102.3
# 356    100.0
# 53      99.0
# 224     93.0
# 711     92.0
# 56      88.4

# %%
elw_zscore.describe(include='all')
# Out:
#         product_id_x  onsale_web_x     price_x  stock_quantity_x stock_status  \
# count     714.000000         714.0  714.000000        714.000000          714
# unique           NaN           NaN         NaN               NaN            2
# top              NaN           NaN         NaN               NaN      instock
# freq             NaN           NaN         NaN               NaN          574
# first            NaN           NaN         NaN               NaN          NaN
# last             NaN           NaN         NaN               NaN          NaN
# mean     5032.557423           1.0   32.493137         28.746499          NaN
# std       790.510878           0.0   27.810525         48.012608          NaN
# min      3847.000000           1.0    5.200000          0.000000          NaN
# 25%      4280.250000           1.0   14.100000          2.000000          NaN
# 50%      4796.000000           1.0   23.550000         12.000000          NaN
# 75%      5710.500000           1.0   42.175000         35.000000          NaN
# max      7338.000000           1.0  225.000000        578.000000          NaN
#
#         id_web tax_status        post_date_gmt  \
# count    714.0        714                  714
# unique   714.0          1                  714
# top       38.0    taxable  2018-04-18 10:25:58
# freq       1.0        714                    1
# first      NaN        NaN  2018-02-08 11:58:52
# last       NaN        NaN  2020-07-20 09:00:00
# mean       NaN        NaN                  NaN
# std        NaN        NaN                  NaN
# min        NaN        NaN                  NaN
# 25%        NaN        NaN                  NaN
# 50%        NaN        NaN                  NaN
# 75%        NaN        NaN                  NaN
# max        NaN        NaN                  NaN
#
#                                              post_excerpt  \
# count                                                 714
# unique                                                677
# top     Les eaux de vie naissent d'une subtile alchimi...
# freq                                                   12
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                post_title  ...  \
# count                                                 714  ...
# unique                                                711  ...
# top     Marc Colin Et Fils Chassagne-Montrachet Blanc ...  ...
# freq                                                    2  ...
# first                                                 NaN  ...
# last                                                  NaN  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#         Chiffre d'affaires_x  % Chiffre d'affaires_x  Outlier / Inliers  \
# count             714.000000              714.000000                714
# unique                   NaN                     NaN                  2
# top                      NaN                     NaN             Inlier
# freq                     NaN                     NaN                682
# first                    NaN                     NaN                NaN
# last                     NaN                     NaN                NaN
# mean               98.835574                0.140000                NaN
# std               307.685071                0.435968                NaN
# min                 0.000000                0.000000                NaN
# 25%                 0.000000                0.000000                NaN
# 50%                15.250000                0.020000                NaN
# 75%                91.150000                0.130000                NaN
# max              4704.000000                6.670000                NaN
#
#         product_id_y  onsale_web_y       price_y  stock_quantity_y  \
# count   7.140000e+02           0.0  7.140000e+02      7.140000e+02
# unique           NaN           NaN           NaN               NaN
# top              NaN           NaN           NaN               NaN
# freq             NaN           NaN           NaN               NaN
# first            NaN           NaN           NaN               NaN
# last             NaN           NaN           NaN               NaN
# mean    3.475472e-16           NaN  1.908682e-16      2.534543e-16
# std     1.000701e+00           NaN  1.000701e+00      1.000701e+00
# min    -1.500787e+00           NaN -9.820840e-01     -5.991478e-01
# 25%    -9.523396e-01           NaN -6.618369e-01     -5.574629e-01
# 50%    -2.994560e-01           NaN -3.217993e-01     -3.490383e-01
# 75%     8.582018e-01           NaN  3.483807e-01      1.303384e-01
# max     2.918440e+00           NaN  6.926939e+00      1.144780e+01
#
#         total_sales_y  Chiffre d'affaires_y  % Chiffre d'affaires_y
# count    7.140000e+02          7.140000e+02            7.140000e+02
# unique            NaN                   NaN                     NaN
# top               NaN                   NaN                     NaN
# freq              NaN                   NaN                     NaN
# first             NaN                   NaN                     NaN
# last              NaN                   NaN                     NaN
# mean     1.388556e-16         -2.116265e-16            3.012685e-16
# std      1.000701e+00          1.000701e+00            1.000701e+00
# min     -4.713937e-01         -3.214484e-01           -3.213495e-01
# 25%     -4.713937e-01         -3.214484e-01           -3.213495e-01
# 50%     -3.539155e-01         -2.718499e-01           -2.754425e-01
# 75%     -1.480818e-03         -2.499621e-02           -2.295354e-02
# max      1.080652e+01          1.497763e+01            1.498866e+01
#
# [13 rows x 21 columns]

# %%
elw_zscore['price_x'][elw_zscore['price_y']<0]
# Out:
# 0       8.6
# 4      22.5
# 13     29.5
# 20     19.5
# 25     12.0
#        ...
# 703    25.2
# 704     9.7
# 705     7.1
# 706    14.1
# 713    25.0
# Name: price_x, Length: 465, dtype: float64

# %%
elw_zscore['price_x'].std()
# Out:
# 27.810524922323708

# %%
elw_zscore['price_x'].mean()
# Out:
# 32.493137254902

# %% [markdown]
# ### 1 ÉCART TYPE= 88,79% **

# %%
elw_zscore[(elw_zscore['price_x']>(32.493137-(27.810525)*1)) 
            & (elw_zscore['price_x']<(32.493137+(27.810525)*1))].count()
# Out:
# product_id_x              634
# onsale_web_x              634
# price_x                   634
# stock_quantity_x          634
# stock_status              634
# id_web                    634
# tax_status                634
# post_date_gmt             634
# post_excerpt              634
# post_title                634
# total_sales_x             634
# Chiffre d'affaires_x      634
# % Chiffre d'affaires_x    634
# Outlier / Inliers         634
# product_id_y              634
# onsale_web_y                0
# price_y                   634
# stock_quantity_y          634
# total_sales_y             634
# Chiffre d'affaires_y      634
# % Chiffre d'affaires_y    634
# dtype: int64

# %% [markdown]
# ### 2 ÉCART TYPE= 95,79% **

# %%
elw_zscore[(elw_zscore['price_x']>(32.493137-(27.810525)*2)) 
            & (elw_zscore['price_x']<(32.493137+(27.810525)*2))].count()
# Out:
# product_id_x              684
# onsale_web_x              684
# price_x                   684
# stock_quantity_x          684
# stock_status              684
# id_web                    684
# tax_status                684
# post_date_gmt             684
# post_excerpt              684
# post_title                684
# total_sales_x             684
# Chiffre d'affaires_x      684
# % Chiffre d'affaires_x    684
# Outlier / Inliers         684
# product_id_y              684
# onsale_web_y                0
# price_y                   684
# stock_quantity_y          684
# total_sales_y             684
# Chiffre d'affaires_y      684
# % Chiffre d'affaires_y    684
# dtype: int64

# %% [markdown]
# ### 3 ÉCART TYPE= 98,03% **

# %%
elw_zscore[(elw_zscore['price_x']>(32.493137-(27.810525)*3)) 
            & (elw_zscore['price_x']<(32.493137+(27.810525)*3))].count()
# Out:
# product_id_x              700
# onsale_web_x              700
# price_x                   700
# stock_quantity_x          700
# stock_status              700
# id_web                    700
# tax_status                700
# post_date_gmt             700
# post_excerpt              700
# post_title                700
# total_sales_x             700
# Chiffre d'affaires_x      700
# % Chiffre d'affaires_x    700
# Outlier / Inliers         700
# product_id_y              700
# onsale_web_y                0
# price_y                   700
# stock_quantity_y          700
# total_sales_y             700
# Chiffre d'affaires_y      700
# % Chiffre d'affaires_y    700
# dtype: int64

# %%
elw_zscore.count()
# Out:
# product_id_x              714
# onsale_web_x              714
# price_x                   714
# stock_quantity_x          714
# stock_status              714
# id_web                    714
# tax_status                714
# post_date_gmt             714
# post_excerpt              714
# post_title                714
# total_sales_x             714
# Chiffre d'affaires_x      714
# % Chiffre d'affaires_x    714
# Outlier / Inliers         714
# product_id_y              714
# onsale_web_y                0
# price_y                   714
# stock_quantity_y          714
# total_sales_y             714
# Chiffre d'affaires_y      714
# % Chiffre d'affaires_y    714
# dtype: int64

# %%
a=el['product_id'].unique()

# %%
a
x=0
for x in a:
    x=x+1

# %%
x
# Out:
# 7339

# %%
a=elw['product_id'].unique()

# %%
a
x=0
for x in a:
    x=x+1

# %%
x
# Out:
# 4955

# %%
liaison['product_id'].count()
# Out:
# 734

# %%
erp['product_id'].count()
# Out:
# 825

# %%
b=web['id_web'].unique()
